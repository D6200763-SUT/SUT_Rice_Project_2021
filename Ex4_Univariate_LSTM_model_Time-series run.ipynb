# %%
import ipywidgets as widgets
from IPython.display import display
from IPython.display import clear_output
import IPython
import IPython.display

import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from pandas import concat
from pandas import DataFrame

import datetime,os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import math
from math import sqrt

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
# File name and Path
cwd = os.getcwd()
path_adress = "/Import_Dataset/"

# ข้อมูล พิกัดสถานที่เเละรายชื้ออ้างอิงสถานที่ตรวจวัด
file_name_st = 'Data_lat_long_Rice research Center'
csv_file_st = cwd + path_adress + file_name_st + '.csv'

df_st = pd.read_csv(csv_file_st)
print("All low RiceCenter {} station" .format(df_st.shape[0]))

data_list_st_num = list(range(0, len(df_st)))
data_list_st_name = []
data_list_st_name = df_st['nameEng'].values.tolist()
data_list_st_lat = df_st['Latitude'].values.tolist()
data_list_st_long = df_st['Longitude'].values.tolist()

#################-- Moving Averag data --#################
def mavr_dataset(frames_sma,rolling_num,our_rate,mode):    
    h_name = list(frames_sma)
    if mode == 'sum':
        frames_sma['mirid bug'] = frames_sma['mirid bug'].rolling(rolling_num, min_periods=1).sum().round(1)
        frames_sma['bph'] = frames_sma['bph'].rolling(rolling_num, min_periods=1).sum().round(1)
        frames_sma['precip'] = frames_sma['precip'].rolling(rolling_num, min_periods=1).sum().round(1)
    else:
        frames_sma['mirid bug'] = frames_sma['mirid bug'].rolling(rolling_num, min_periods=1).mean().round(1)
        frames_sma['bph'] = frames_sma['bph'].rolling(rolling_num, min_periods=1).mean().round(1)
        frames_sma['precip'] = frames_sma['precip'].rolling(rolling_num, min_periods=1).mean().round(1)
   
    for i in range(7,12):
        frames_sma[h_name[i]] = frames_sma[h_name[i]].rolling(rolling_num, min_periods=1).mean().round(1)

    constant_subset = frames_sma[::our_rate] 
    return constant_subset

#################-- creat_dataset  --#################
def creat_dataset(st_BPH = 'ALL', y_1='2015', y_2='2019', m_avr='ALL'):
    for i in range(len(data_list_st_num)):
        st = i
        file_name = df_st['nameEng'][data_list_st_num[st]]
        name_input = file_name
        name_locals = 'stN_' + file_name

        # File name and Path
        csv_file = cwd + path_adress + name_input + '.csv'
        # index_col=0 , index_col=None
        dataset = pd.read_csv(csv_file, header=0,
                              index_col=0, encoding="TIS-620")

        if m_avr == '3-DAY-All-':
            locals()[name_locals] = mavr_dataset(dataset,3,1,'mean')
        elif m_avr == '7-DAY-All':
            locals()[name_locals] = mavr_dataset(dataset,7,1,'mean')
        elif m_avr == '14-DAY-All':
            locals()[name_locals] = mavr_dataset(dataset,14,1,'mean')
        elif m_avr == '3-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,3,3,'sum')
        elif m_avr == '7-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,7,7,'sum')
        elif m_avr == '14-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,14,14,'sum')
        else :
            locals()[name_locals] = dataset
            # print(f'Dataframe name_station: {st+1 , name_input}')
        print('wait......')
        del dataset
        clear_output(wait=True)

    date_start = y_1 + '-01' + '-01'
    date_stop = y_2 + '-12' + '-31'

#---------------------------------------------------------------------------------------------------------------------------------------------------#
    if st_BPH != 'ALL' :
        # file_name = df_st['nameEng'][data_list_st_num[st_BPH]]
        file_name = st_BPH
        locals_input = 'stN_' + file_name
        print(locals_input)
        dataset_st = locals()[locals_input].loc[date_start:date_stop]
        frames_st = dataset_st
    else:
        m = 0
        for j in range(len(data_list_st_num)):
            # for j in range(df_st.shape[0]):
            # file_name = df_st['nameEng'][j]
            file_name = df_st['nameEng'][data_list_st_num[j]]
            locals_input = 'stN_' + file_name
            print(locals_input)
            dataset_st = locals()[locals_input].loc[date_start:date_stop]
            clear_output(wait=True)
            if m == 0:
                frames_st = dataset_st
                m = m+1
                print(m)
            else:
                frames_st = [frames_st, dataset_st]
                frames_st = pd.concat(frames_st)

    # dataset    
    frames = frames_st
    return frames
#---------------------------------------------------------------------------------------------------------------------------------------------------#

#################-- Drop Colum  --#################
def drop_col(df_drop,drop = ['address']):
    for j in range(len(drop)):
        df_drop = df_drop.drop(drop[j], axis=1)
    return df_drop

#################--      Plot        --#################
def plot_data(frames_train,plot_cols,df_name,start='2015',end='2017',st = 'ALL'):
    #ตรวจสอบข้อมูล dataset 
    if st == 'ALL':
        df_plot = frames_train[plot_cols]
    else:
        df_plot = frames_train[plot_cols].loc[start:end]
    
    plt.figure()    
    # df_plot.plot(lw=1,grid=True,figsize=(13,30),subplots=True)
    # df_plot.plot(lw=1,grid=True,subplots=True)
    # df_plot.plot(marker='.',grid=True,linestyle = 'solid',subplots=True)
    df_plot.plot(marker='.',grid=True,linestyle = 'solid')
    plt.xlabel('Date time-'+ df_name)
    plt.legend()
    # plt.show()   

#################--   get list of folders in directory   --#################
dir_path = cwd + "/Export_lstm/model/"
def get_list_folder():
    folder_list = os.listdir(dir_path)
    return folder_list

def get_file_model(file_name):
    txt = dir_path+file_name+"/Training_model_data_discription.txt"
    string_data = open(txt,"r").read()
    list_txt = list(string_data.split("\n"))
    return list_txt
# Out:
# All low RiceCenter 34 station

# %%
#########################################-- Dashboard Input Data--#########################################
ALL = 'ALL'

def unique_sorted_values_plus_ALL(array):
    unique = array.unique().tolist()
    unique.sort()
    unique.insert(0, ALL)
    return unique

#################-- DataFrame station --#################
output_df_st = widgets.Output()
def dropdown_station_eventhandler(change):
    output_df_st.clear_output()
    with output_df_st:  
        if (change.new == ALL):
            display(df_st)
        else:
            display(df_st[df_st.nameEng == change.new])

#################-- DataFrame station --#################
output_df_st_predict = widgets.Output()
def dropdown_station_predict_eventhandler(change):
    output_df_st_predict.clear_output()
    with output_df_st_predict:  
        if (change.new == ALL):
            display(df_st)
        else:
            display(df_st[df_st.nameEng == change.new])

#################-- load data  --#################


output_df_train = widgets.Output()
output_df_val = widgets.Output()
output_df_test = widgets.Output()
output_df_col = widgets.Output()
def clicked_load(b):
    global df_out_train
    global df_out_val
    global df_out_test
    global selected_data 
    output_df_train.clear_output()
    output_df_val.clear_output()
    output_df_test.clear_output()
    output_df_col.clear_output()
    with output_df_train:
        df_out_train = creat_dataset(dropdown_name_st.value,dropdown_year_train1.value,dropdown_year_train2.value,dropdown_sampling_data.value)
        display(df_out_train)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_train1.value,dropdown_year_train2.value,dropdown_sampling_data.value))
    with output_df_val:
        df_out_val = creat_dataset(dropdown_name_st.value,dropdown_year_val1.value,dropdown_year_val2.value,dropdown_sampling_data.value)
        display(df_out_val)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_val1.value,dropdown_year_val2.value,dropdown_sampling_data.value))
    with output_df_test:
        df_out_test = creat_dataset(dropdown_name_st.value,dropdown_year_test1.value,dropdown_year_test2.value,dropdown_sampling_data.value)
        display(df_out_test)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_test1.value,dropdown_year_test2.value,dropdown_sampling_data.value))
    with output_df_col:
        checkbox_objects = []
        # global selected_data
        data = sorted(set(chek_list(df_out_train)),reverse=True)     
        names = []
        for key in data:
                checkbox_objects.append(widgets.Checkbox(value=True, description=key))
                names.append(key)
 
        arg_dict = {names[i]: checkbox for i, checkbox in enumerate(checkbox_objects)}
        ui = widgets.HBox(children=checkbox_objects)
        display(ui)
             
        selected_data = []
        def select_data(**kwargs):
            selected_data.clear()
            for key in kwargs:
                if kwargs[key] is True:
                    selected_data.append(key)
            print(selected_data)

        widgets.interactive_output(select_data, arg_dict)
    
 
#################-- Export data  --#################
df_train = widgets.Output()
df_val = widgets.Output()
df_test = widgets.Output()
def clicked_export(b):
    df_train.clear_output()
    df_val.clear_output()
    df_test.clear_output()
    global frames_train
    global frames_val
    global frames_test
    with df_train:
        frames_train = drop_col(df_out_train,selected_data) 
        display(frames_train)
    with df_val:
        frames_val = drop_col(df_out_val,selected_data) 
        display(frames_val)  
    with df_test:
        frames_test = drop_col(df_out_test,selected_data) 
        display(frames_test)  

def chek_list(df_ch):
        data_col = set(df_ch.columns)
        return data_col      

#################----------------------------- DashBoard display ----------------------------------#################
dropdown_name_st = widgets.Dropdown(options = unique_sorted_values_plus_ALL(df_st.nameEng),description='station :')
dropdown_sampling_data = widgets.Dropdown(options = ['All','3-DAY-All','7-DAY-All','14-DAY-All','3-DAY-Sampling','7-DAY-Sampling','14-DAY-Sampling'],valure = 'All-DAY',description='Sampling :')
dropdown_year_train1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],description='Year-train :')
dropdown_year_train2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2017')
dropdown_year_val1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2018',description='Year-val :')
dropdown_year_val2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2018')
dropdown_year_test1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2019',description='Year-test :')
dropdown_year_test2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2019')


button_download = widgets.Button(description='load data',disabled=False,button_style='success',tooltip='Click me',icon='check')
button_export = widgets.Button(description='export dataset',disabled=False,button_style='success',tooltip='Click me',icon='check')

button_download.on_click(clicked_load)
button_export.on_click(clicked_export)

dropdown_name_st.observe(dropdown_station_eventhandler, names='value')


item_layout = widgets.Layout(margin='0 0 15px 0')
input_widgets_row1 = widgets.HBox([dropdown_name_st,dropdown_year_train1,dropdown_year_train2,dropdown_year_val1,dropdown_year_val2,dropdown_year_test1,dropdown_year_test2],layout = item_layout)
input_widgets_row2 = widgets.HBox([dropdown_sampling_data,button_download,button_export],layout = item_layout)

tab_dataset = widgets.Tab([output_df_st,output_df_train,output_df_val,output_df_test,output_df_col,df_train,df_val,df_test])
tab_dataset.set_title(0, 'Dataset station')
tab_dataset.set_title(1, 'train-data')
tab_dataset.set_title(2, 'validation-data')
tab_dataset.set_title(3, 'test-data')
tab_dataset.set_title(4, 'Drop-data')
tab_dataset.set_title(5, 'Dataset-train')
tab_dataset.set_title(6, 'Dataset-validation')
tab_dataset.set_title(7, 'Dataset-test')
dashboard_dataset = widgets.VBox([input_widgets_row1,input_widgets_row2])
display(dashboard_dataset)
display(tab_dataset)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='station :', options=('ALL', 'Chachoengsao Rice research Ce…
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), _titles={'0': '…

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
def plot_data(frames_train,df_name):
    #ตรวจสอบข้อมูล dataset 
    plt.figure()
    df_plot = frames_train
    df_plot.plot(lw=1,grid=True,subplots=True)
    plt.xlabel('Date time-'+ df_name)
    plt.legend()
    # plt.show()

# %%
day_of_month = frames_train['day'].values
month_of_year = frames_train['month'].values

frames_train['d_sin'] = np.sin((2*np.pi)/30*frames_train['day'].values)
frames_train['d_cos'] = np.cos((2*np.pi)/30*frames_train['day'].values)
frames_train['m_sin'] = np.sin((2*np.pi)/12*frames_train['month'].values)
frames_train['m_cos'] = np.cos((2*np.pi)/12*frames_train['month'].values)
frames_train = frames_train.drop(['day', 'month'], axis=1)

frames_val['d_sin'] = np.sin((2*np.pi)/30*frames_val['day'].values)
frames_val['d_cos'] = np.cos((2*np.pi)/30*frames_val['day'].values)
frames_val['m_sin'] = np.sin((2*np.pi)/12*frames_val['month'].values)
frames_val['m_cos'] = np.cos((2*np.pi)/12*frames_val['month'].values)
frames_val = frames_val.drop(['day', 'month'], axis=1)


frames_test['d_sin'] = np.sin((2*np.pi)/30*frames_test['day'].values)
frames_test['d_cos'] = np.cos((2*np.pi)/30*frames_test['day'].values)
frames_test['m_sin'] = np.sin((2*np.pi)/12*frames_test['month'].values)
frames_test['m_cos'] = np.cos((2*np.pi)/12*frames_test['month'].values)
frames_test = frames_test.drop(['day', 'month'], axis=1)

#define function to swap columns
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

#swap points and rebounds columns
frames_train = swap_columns(frames_train, 'bph', list(frames_train.columns)[-1])
frames_val = swap_columns(frames_val, 'bph', list(frames_val.columns)[-1])
frames_test = swap_columns(frames_test, 'bph', list(frames_test.columns)[-1])

# %%
values_train = frames_train.values    
n_features = frames_train.shape[1]

values_validation = frames_val.values
plot_data(frames_train,'test')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

n_day = 7
n_out = 3

#train data
# ensure all data is float
values = values_train.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)
# print(reframed.shape)
# print(reframed.head())

# predict datasets
values = reframed.values
train = values

#input 
n_obs = n_day * n_features
# train_X, train_y = train[:, :n_obs], train[:, -n_features]
train_X, train_y = train[:, :n_obs], train[:, -1]
print(train_X.shape, len(train_X), train_y.shape)  #for train


# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_day, n_features))
print(train_X.shape, train_y.shape)

#validation data
# ensure all data is float
values = values_validation.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)

# predict datasets
values = reframed.values
test = values

#output 
n_obs = n_day * n_features
# test_X, test_y = test[:, :n_obs], test[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(test_X.shape, len(test_X), test_y.shape)  #for train

# reshape input to be 3D [samples, timesteps, features]
test_X = test_X.reshape((test_X.shape[0], n_day, n_features))
print(test_X.shape, test_y.shape)


##------train-----##
model = tf.keras.models.Sequential([
                  # Shape [batch, time, features] => [batch, time, lstm_units]
                  keras.layers.LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2]),activation='relu'),  #relu tanh
                  keras.layers.Dense(units=1)
    ])
# model = tf.keras.models.Sequential([
#                   # Shape [batch, time, features] => [batch, time, lstm_units]
#                   keras.layers.LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]),return_sequences=True,activation='relu'),
#                   keras.layers.BatchNormalization(),
#                   keras.layers.Dropout(0.1),
#                   keras.layers.LSTM(50, return_sequences=True, activation='relu'),
#                   keras.layers.BatchNormalization(),
#                   keras.layers.Dropout(0.1),
#                   keras.layers.LSTM(50, activation='relu'),
#                   keras.layers.BatchNormalization(),
#                   keras.layers.Dropout(0.1),
#                   keras.layers.Dense(units=1)
#             ])            
Optimizer = tf.keras.optimizers.Adam(0.0001)
model.compile(Optimizer, loss='mae', metrics=['accuracy'])
# model.summary()

# fit network
Epochs = 2000
batch_size = 128
history = model.fit(train_X, train_y, 
                    epochs=Epochs, 
                    batch_size=batch_size, 
                    validation_data=(test_X, test_y), 
                    verbose=2, 
                    # callbacks=[cp_callback,es_callback], 
                    shuffle=False)

# plot history
from matplotlib import pyplot as plt
def plot_loss(history):
    plt.figure()
    plt.plot(history.history['loss'], label='train')
    # plt.plot(history.history['val_loss'], label='val')
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)
#     plt.show()

plot_loss(history)
# Out:
# (37255, 42) 37255 (37255,)
# (37255, 7, 6) (37255,)
# (12401, 42) 12401 (12401,)
# (12401, 7, 6) (12401,)
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/2000
# 292/292 - 3s - loss: 0.0125 - accuracy: 0.4064 - val_loss: 0.0107 - val_accuracy: 0.4859 - 3s/epoch - 10ms/step
# Epoch 2/2000
# 292/292 - 2s - loss: 0.0056 - accuracy: 0.4064 - val_loss: 0.0094 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 3/2000
# 292/292 - 2s - loss: 0.0051 - accuracy: 0.4064 - val_loss: 0.0088 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 4/2000
# 292/292 - 2s - loss: 0.0044 - accuracy: 0.4064 - val_loss: 0.0084 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 5/2000
# 292/292 - 2s - loss: 0.0041 - accuracy: 0.4064 - val_loss: 0.0078 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 6/2000
# 292/292 - 2s - loss: 0.0039 - accuracy: 0.4064 - val_loss: 0.0074 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 7/2000
# 292/292 - 2s - loss: 0.0037 - accuracy: 0.4064 - val_loss: 0.0070 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 8/2000
# 292/292 - 2s - loss: 0.0035 - accuracy: 0.4064 - val_loss: 0.0069 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 9/2000
# 292/292 - 2s - loss: 0.0034 - accuracy: 0.4064 - val_loss: 0.0064 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 10/2000
# 292/292 - 2s - loss: 0.0032 - accuracy: 0.4064 - val_loss: 0.0061 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 11/2000
# 292/292 - 2s - loss: 0.0031 - accuracy: 0.4064 - val_loss: 0.0058 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 12/2000
# 292/292 - 2s - loss: 0.0030 - accuracy: 0.4064 - val_loss: 0.0056 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 13/2000
# 292/292 - 2s - loss: 0.0026 - accuracy: 0.4064 - val_loss: 0.0054 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 14/2000
# 292/292 - 2s - loss: 0.0025 - accuracy: 0.4064 - val_loss: 0.0054 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 15/2000
# 292/292 - 2s - loss: 0.0024 - accuracy: 0.4064 - val_loss: 0.0051 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 16/2000
# 292/292 - 2s - loss: 0.0023 - accuracy: 0.4064 - val_loss: 0.0049 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 17/2000
# 292/292 - 2s - loss: 0.0023 - accuracy: 0.4064 - val_loss: 0.0048 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 18/2000
# 292/292 - 2s - loss: 0.0022 - accuracy: 0.4064 - val_loss: 0.0049 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 19/2000
# 292/292 - 2s - loss: 0.0022 - accuracy: 0.4064 - val_loss: 0.0047 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 20/2000
# 292/292 - 2s - loss: 0.0021 - accuracy: 0.4064 - val_loss: 0.0045 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 21/2000
# 292/292 - 2s - loss: 0.0021 - accuracy: 0.4064 - val_loss: 0.0047 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 22/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0044 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 23/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0045 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 24/2000
# 292/292 - 2s - loss: 0.0021 - accuracy: 0.4064 - val_loss: 0.0043 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 25/2000
# 292/292 - 2s - loss: 0.0021 - accuracy: 0.4064 - val_loss: 0.0043 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 26/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0044 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 27/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0043 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 28/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0042 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 29/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0042 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 30/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0043 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 31/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0050 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 32/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0042 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 33/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0046 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 34/2000
# 292/292 - 2s - loss: 0.0020 - accuracy: 0.4064 - val_loss: 0.0042 - val_accuracy: 0.4859 - 2s/epoch - 8ms/step
# Epoch 35/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0047 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 36/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0041 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 37/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0042 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 38/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0041 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 39/2000
# 292/292 - 2s - loss: 0.0018 - accuracy: 0.4064 - val_loss: 0.0043 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 40/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0049 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 41/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0044 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 42/2000
# 292/292 - 2s - loss: 0.0018 - accuracy: 0.4064 - val_loss: 0.0039 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 43/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0039 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 44/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0042 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 45/2000
# 292/292 - 2s - loss: 0.0018 - accuracy: 0.4064 - val_loss: 0.0039 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 46/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0040 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 47/2000
# 292/292 - 2s - loss: 0.0019 - accuracy: 0.4064 - val_loss: 0.0039 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 48/2000
# 292/292 - 2s - loss: 0.0018 - accuracy: 0.4064 - val_loss: 0.0037 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 49/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0037 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 50/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0037 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 51/2000
# 292/292 - 2s - loss: 0.0018 - accuracy: 0.4064 - val_loss: 0.0037 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 52/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0041 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 53/2000
# 292/292 - 2s - loss: 0.0018 - accuracy: 0.4064 - val_loss: 0.0038 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 54/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0043 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 55/2000
# 292/292 - 2s - loss: 0.0018 - accuracy: 0.4064 - val_loss: 0.0038 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 56/2000
# 292/292 - 2s - loss: 0.0018 - accuracy: 0.4064 - val_loss: 0.0037 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 57/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0037 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 58/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0035 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 59/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0035 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 60/2000
# 292/292 - 2s - loss: 0.0016 - accuracy: 0.4064 - val_loss: 0.0034 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 61/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0034 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 62/2000
# 292/292 - 2s - loss: 0.0017 - accuracy: 0.4064 - val_loss: 0.0034 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 63/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0033 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 64/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0033 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 65/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 66/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0031 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 67/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0031 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 68/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 69/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0033 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 70/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 71/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 72/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 73/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 74/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0031 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 75/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 76/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0038 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 77/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 78/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 79/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 80/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0036 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 81/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 82/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 83/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 84/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0033 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 85/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 86/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 87/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 88/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 89/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 90/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 91/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 92/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0031 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 93/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0031 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 94/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 95/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 96/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 97/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0035 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 98/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 99/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 100/2000
# 292/292 - 2s - loss: 0.0015 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 101/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 102/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 103/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 104/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 105/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 106/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 107/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 108/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 109/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 110/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 111/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 112/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 113/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 114/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 115/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 116/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 117/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 118/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0032 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 119/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 120/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 121/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 122/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 123/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 124/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 125/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 126/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 127/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 128/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 129/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 130/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 131/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 132/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 133/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 134/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 135/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 136/2000
# 292/292 - 2s - loss: 0.0014 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 137/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 138/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 139/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 140/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0031 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 141/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 142/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 143/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 144/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 145/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 146/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 147/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 148/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 149/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 150/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 151/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 152/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 153/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 154/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 155/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 156/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 157/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 158/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 159/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 160/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 161/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 162/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 163/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 164/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 165/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 166/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 167/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 168/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 169/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 170/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 171/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 172/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 173/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 174/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 175/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 176/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 177/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 178/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 179/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 180/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 181/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 182/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 183/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 184/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 185/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 186/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 187/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 188/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 189/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 190/2000
# 292/292 - 2s - loss: 0.0013 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 191/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 192/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 193/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 194/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 195/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 196/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0031 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 197/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 198/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 199/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 200/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 201/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 202/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 203/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 204/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 205/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 206/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 207/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 208/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 209/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 210/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 211/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 212/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 213/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 214/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 215/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 216/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 217/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 218/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 219/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 220/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 221/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 222/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 223/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 224/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 225/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 226/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 227/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 228/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 229/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 230/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0034 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 231/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 232/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 233/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 234/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 235/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 236/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 237/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 238/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 239/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 240/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 241/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 242/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 243/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 244/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 245/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 246/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 247/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 248/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 249/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 250/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 251/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 252/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 253/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 254/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0030 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 255/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 256/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 257/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 258/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 259/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 260/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 261/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 262/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 263/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 264/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 265/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 266/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 267/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 268/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 269/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 270/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 271/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 272/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 273/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 274/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 275/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 276/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 277/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 278/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 279/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 280/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 281/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 282/2000
# 292/292 - 2s - loss: 9.9730e-04 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 283/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 284/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 285/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 286/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 287/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 288/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 289/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 290/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 291/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 292/2000
# 292/292 - 2s - loss: 0.0012 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 293/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 294/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 295/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 296/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 297/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 298/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 299/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 300/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 301/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 302/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 303/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 304/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 305/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 306/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 307/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 308/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 309/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 310/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 311/2000
# 292/292 - 2s - loss: 9.8428e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 312/2000
# 292/292 - 2s - loss: 9.9413e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 313/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 314/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 315/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 316/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 317/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 318/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 319/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 320/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 321/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 322/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 323/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 324/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 325/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 326/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 327/2000
# 292/292 - 2s - loss: 9.7439e-04 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 328/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 329/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 330/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 331/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 332/2000
# 292/292 - 2s - loss: 9.8901e-04 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 333/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 334/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 335/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 336/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 337/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 338/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 339/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 8ms/step
# Epoch 340/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 341/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 342/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 343/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 344/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 345/2000
# 292/292 - 2s - loss: 9.7893e-04 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 346/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 347/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 348/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 349/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 350/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 351/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 352/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 353/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 354/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 355/2000
# 292/292 - 2s - loss: 9.8374e-04 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 356/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 357/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 358/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0029 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 359/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 360/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0022 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 361/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 362/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 363/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 364/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 365/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 366/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 367/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 368/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 369/2000
# 292/292 - 2s - loss: 9.9462e-04 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 370/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 371/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 372/2000
# 292/292 - 2s - loss: 9.7237e-04 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 373/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0022 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 374/2000
# 292/292 - 2s - loss: 9.7838e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 375/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 376/2000
# 292/292 - 2s - loss: 0.0010 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 377/2000
# 292/292 - 2s - loss: 9.8307e-04 - accuracy: 0.4064 - val_loss: 0.0023 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 378/2000
# 292/292 - 2s - loss: 9.9058e-04 - accuracy: 0.4064 - val_loss: 0.0028 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 379/2000
# 292/292 - 2s - loss: 0.0011 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 380/2000
# ...
# Epoch 1879/2000
# 292/292 - 2s - loss: 7.2840e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1880/2000
# 292/292 - 2s - loss: 7.5263e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1881/2000
# 292/292 - 2s - loss: 7.4521e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1882/2000
# 292/292 - 2s - loss: 6.8520e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1883/2000
# 292/292 - 2s - loss: 6.9655e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1884/2000
# 292/292 - 2s - loss: 7.3779e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1885/2000
# 292/292 - 2s - loss: 7.3659e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1886/2000
# 292/292 - 2s - loss: 7.3405e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1887/2000
# 292/292 - 2s - loss: 7.3138e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1888/2000
# 292/292 - 2s - loss: 7.0300e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1889/2000
# 292/292 - 2s - loss: 7.3013e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1890/2000
# 292/292 - 2s - loss: 7.0335e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1891/2000
# 292/292 - 2s - loss: 7.1432e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1892/2000
# 292/292 - 2s - loss: 7.1285e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1893/2000
# 292/292 - 2s - loss: 7.5483e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1894/2000
# 292/292 - 2s - loss: 7.1975e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1895/2000
# 292/292 - 2s - loss: 6.8835e-04 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1896/2000
# 292/292 - 2s - loss: 7.2666e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1897/2000
# 292/292 - 2s - loss: 7.3158e-04 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1898/2000
# 292/292 - 2s - loss: 6.9176e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1899/2000
# 292/292 - 2s - loss: 6.8774e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1900/2000
# 292/292 - 2s - loss: 7.1019e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1901/2000
# 292/292 - 2s - loss: 7.3200e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1902/2000
# 292/292 - 2s - loss: 6.9487e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1903/2000
# 292/292 - 2s - loss: 7.0689e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1904/2000
# 292/292 - 2s - loss: 7.3331e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1905/2000
# 292/292 - 2s - loss: 7.1752e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1906/2000
# 292/292 - 2s - loss: 6.9864e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1907/2000
# 292/292 - 2s - loss: 7.4305e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1908/2000
# 292/292 - 2s - loss: 7.0021e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1909/2000
# 292/292 - 2s - loss: 6.7974e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1910/2000
# 292/292 - 2s - loss: 7.3853e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1911/2000
# 292/292 - 2s - loss: 7.3736e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1912/2000
# 292/292 - 2s - loss: 7.0760e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1913/2000
# 292/292 - 2s - loss: 7.0743e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1914/2000
# 292/292 - 2s - loss: 7.0401e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1915/2000
# 292/292 - 2s - loss: 6.9847e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1916/2000
# 292/292 - 2s - loss: 7.3252e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1917/2000
# 292/292 - 2s - loss: 7.4592e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1918/2000
# 292/292 - 2s - loss: 7.1435e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1919/2000
# 292/292 - 2s - loss: 6.8889e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1920/2000
# 292/292 - 2s - loss: 7.1811e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1921/2000
# 292/292 - 2s - loss: 7.3562e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1922/2000
# 292/292 - 2s - loss: 6.9643e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1923/2000
# 292/292 - 2s - loss: 7.0120e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1924/2000
# 292/292 - 2s - loss: 7.3643e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1925/2000
# 292/292 - 2s - loss: 7.7335e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1926/2000
# 292/292 - 2s - loss: 6.8256e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1927/2000
# 292/292 - 2s - loss: 7.1023e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1928/2000
# 292/292 - 2s - loss: 7.4667e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1929/2000
# 292/292 - 2s - loss: 7.4941e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 1930/2000
# 292/292 - 2s - loss: 7.1866e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1931/2000
# 292/292 - 2s - loss: 7.3809e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1932/2000
# 292/292 - 2s - loss: 7.1201e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1933/2000
# 292/292 - 2s - loss: 6.8175e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1934/2000
# 292/292 - 2s - loss: 7.2946e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1935/2000
# 292/292 - 2s - loss: 6.9630e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1936/2000
# 292/292 - 2s - loss: 7.1815e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1937/2000
# 292/292 - 2s - loss: 6.9658e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1938/2000
# 292/292 - 2s - loss: 7.2331e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1939/2000
# 292/292 - 2s - loss: 7.0641e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1940/2000
# 292/292 - 2s - loss: 7.1298e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1941/2000
# 292/292 - 2s - loss: 7.1575e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1942/2000
# 292/292 - 2s - loss: 7.3394e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1943/2000
# 292/292 - 2s - loss: 7.4871e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1944/2000
# 292/292 - 2s - loss: 7.3204e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1945/2000
# 292/292 - 2s - loss: 6.7533e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1946/2000
# 292/292 - 2s - loss: 7.0477e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1947/2000
# 292/292 - 2s - loss: 7.1579e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1948/2000
# 292/292 - 2s - loss: 7.4032e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1949/2000
# 292/292 - 2s - loss: 7.0451e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1950/2000
# 292/292 - 2s - loss: 6.7721e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1951/2000
# 292/292 - 2s - loss: 6.8194e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1952/2000
# 292/292 - 2s - loss: 7.1633e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1953/2000
# 292/292 - 2s - loss: 7.1822e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1954/2000
# 292/292 - 2s - loss: 7.1170e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1955/2000
# 292/292 - 2s - loss: 7.2268e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1956/2000
# 292/292 - 2s - loss: 7.0722e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1957/2000
# 292/292 - 2s - loss: 7.3717e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1958/2000
# 292/292 - 2s - loss: 7.1087e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1959/2000
# 292/292 - 2s - loss: 6.7484e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 1960/2000
# 292/292 - 2s - loss: 7.5254e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1961/2000
# 292/292 - 2s - loss: 7.2277e-04 - accuracy: 0.4064 - val_loss: 0.0024 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1962/2000
# 292/292 - 2s - loss: 6.9373e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1963/2000
# 292/292 - 2s - loss: 7.1659e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1964/2000
# 292/292 - 2s - loss: 7.6377e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1965/2000
# 292/292 - 2s - loss: 7.2283e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1966/2000
# 292/292 - 2s - loss: 7.3653e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1967/2000
# 292/292 - 2s - loss: 7.1705e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1968/2000
# 292/292 - 2s - loss: 7.1410e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1969/2000
# 292/292 - 2s - loss: 7.0068e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 1970/2000
# 292/292 - 2s - loss: 7.3482e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1971/2000
# 292/292 - 2s - loss: 6.9865e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1972/2000
# 292/292 - 2s - loss: 6.9931e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1973/2000
# 292/292 - 2s - loss: 6.9720e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1974/2000
# 292/292 - 2s - loss: 6.9839e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1975/2000
# 292/292 - 2s - loss: 7.2969e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1976/2000
# 292/292 - 2s - loss: 7.3372e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1977/2000
# 292/292 - 2s - loss: 7.1982e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1978/2000
# 292/292 - 2s - loss: 7.5887e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1979/2000
# 292/292 - 2s - loss: 7.1183e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 1980/2000
# 292/292 - 2s - loss: 7.1387e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1981/2000
# 292/292 - 2s - loss: 7.3860e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1982/2000
# 292/292 - 2s - loss: 7.3801e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1983/2000
# 292/292 - 2s - loss: 6.9371e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 7ms/step
# Epoch 1984/2000
# 292/292 - 2s - loss: 7.0729e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1985/2000
# 292/292 - 2s - loss: 6.8758e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1986/2000
# 292/292 - 2s - loss: 6.9315e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1987/2000
# 292/292 - 2s - loss: 7.2677e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1988/2000
# 292/292 - 2s - loss: 7.0927e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1989/2000
# 292/292 - 2s - loss: 7.0521e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1990/2000
# 292/292 - 2s - loss: 6.8721e-04 - accuracy: 0.4064 - val_loss: 0.0026 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1991/2000
# 292/292 - 2s - loss: 7.0333e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1992/2000
# 292/292 - 2s - loss: 7.3314e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1993/2000
# 292/292 - 2s - loss: 6.7890e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1994/2000
# 292/292 - 2s - loss: 7.2526e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1995/2000
# 292/292 - 2s - loss: 6.9478e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1996/2000
# 292/292 - 2s - loss: 6.9649e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1997/2000
# 292/292 - 2s - loss: 7.2308e-04 - accuracy: 0.4064 - val_loss: 0.0027 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 1998/2000
# 292/292 - 2s - loss: 7.3862e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step
# Epoch 1999/2000
# 292/292 - 2s - loss: 7.2375e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 6ms/step
# Epoch 2000/2000
# 292/292 - 2s - loss: 7.3486e-04 - accuracy: 0.4064 - val_loss: 0.0025 - val_accuracy: 0.4859 - 2s/epoch - 5ms/step

# %%
values_predict = frames_test.values
n_features = frames_test.shape[1]
df = frames_test.reset_index()
date_time_predict = pd.to_datetime(df.pop('date'))

# ensure all data is float
values = values_predict.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
    
# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)
# print(reframed.shape)
# print(reframed.head())
    
# predict datasets
values = reframed.values
# n_train_day = int(values.shape[0]*0.9)
# train = values[:n_train_day, :]
test = values
    
# predict into input and outputs
n_obs = n_day * n_features
# test_X, test_y = test[:, :n_obs], test[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(test_X.shape, len(test_X), test_y.shape)
    
# reshape input to be 3D [samples, timesteps, features]
test_X = test_X.reshape((test_X.shape[0], n_day, n_features))
print(test_X.shape, test_y.shape)
    
# # make a prediction
yhat = model.predict(test_X,verbose=0)
test_X_reshape = test_X.reshape((test_X.shape[0], n_day*n_features)) 

from cProfile import label
from numpy import concatenate

# invert scaling for forecast
# inv_yhat = concatenate((yhat, test_X[:, -29:]), axis=1)
inv_yhat = concatenate((test_X_reshape[:, :(n_features-1)], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y_reshape = test_y.reshape((len(test_y), 1))
# inv_y = concatenate((test_y, test_X[:, -29:]), axis=1)
inv_y = concatenate((test_X_reshape[:, :(n_features-1)], test_y_reshape), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]

d_range = 60
pre_start = 200 #0  200
pre_stop = pre_start+d_range
d_start = n_day+n_out-1+pre_start
d_stop = n_day+n_out-1+pre_start+d_range


# calculate RMSE
m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(inv_y[pre_start:pre_stop], inv_yhat[pre_start:pre_stop])
rmse = m.result().numpy()
print('RMSE: %.3f' % rmse)


strings = list(frames_test.columns)
textstr = '\n'.join(strings[:12])

fig, ax = plt.subplots()

# ax.plot(date_time_predict[n_day+n_out-1:],inv_y[:],label='actual')
# ax.plot(date_time_predict[n_day+n_out-1:],inv_yhat[:],label='predict')

ax.plot(date_time_predict[d_start:d_stop],inv_y[pre_start:pre_stop],label='actual')
ax.plot(date_time_predict[d_start:d_stop],inv_yhat[pre_start:pre_stop],label='predict')

ax.legend(loc='upper right')
ax.set_title('Multivariate' +'  RMSE: %.2f' % rmse)
ax.set_xlabel('time (day) '+'(%d-'%n_day+'%d-'%n_out+'Epoch %d)'%Epochs)
ax.set_ylabel('BPH Volume')
ax.grid(True)

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=8,
        verticalalignment='top', bbox=props)
plt.show()
# Out:
# (12401, 42) 12401 (12401,)
# (12401, 7, 6) (12401,)
# RMSE: 60.885
