# %%
import ipywidgets as widgets
from IPython.display import display
from IPython.display import clear_output
import IPython
import IPython.display

import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from pandas import concat
from pandas import DataFrame

import datetime,os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import math
from math import sqrt

# %%
# File name and Path
cwd = os.getcwd()
path_adress = "/Import_Dataset/"

# ข้อมูล พิกัดสถานที่เเละรายชื้ออ้างอิงสถานที่ตรวจวัด
file_name_st = 'Data_lat_long_Rice research Center'
csv_file_st = cwd + path_adress + file_name_st + '.csv'

df_st = pd.read_csv(csv_file_st)
print("All low RiceCenter {} station" .format(df_st.shape[0]))

data_list_st_num = list(range(0, len(df_st)))
data_list_st_name = []
data_list_st_name = df_st['nameEng'].values.tolist()
data_list_st_lat = df_st['Latitude'].values.tolist()
data_list_st_long = df_st['Longitude'].values.tolist()

#################-- Moving Averag data --#################
def mavr_dataset(frames_sma,rolling_num,our_rate,mode):    
    h_name = list(frames_sma)
    if mode == 'sum':
        frames_sma['mirid bug'] = frames_sma['mirid bug'].rolling(rolling_num, min_periods=1).sum().round(1)
        frames_sma['bph'] = frames_sma['bph'].rolling(rolling_num, min_periods=1).sum().round(1)
        frames_sma['precip'] = frames_sma['precip'].rolling(rolling_num, min_periods=1).sum().round(1)
    else:
        frames_sma['mirid bug'] = frames_sma['mirid bug'].rolling(rolling_num, min_periods=1).mean().round(1)
        frames_sma['bph'] = frames_sma['bph'].rolling(rolling_num, min_periods=1).mean().round(1)
        frames_sma['precip'] = frames_sma['precip'].rolling(rolling_num, min_periods=1).mean().round(1)
   
    for i in range(7,12):
        frames_sma[h_name[i]] = frames_sma[h_name[i]].rolling(rolling_num, min_periods=1).mean().round(1)

    constant_subset = frames_sma[::our_rate] 
    return constant_subset

#################-- creat_dataset  --#################
def creat_dataset(st_BPH = 'ALL', y_1='2015', y_2='2019', m_avr='ALL'):
    for i in range(len(data_list_st_num)):
        st = i
        file_name = df_st['nameEng'][data_list_st_num[st]]
        name_input = file_name
        name_locals = 'stN_' + file_name

        # File name and Path
        csv_file = cwd + path_adress + name_input + '.csv'
        # index_col=0 , index_col=None
        dataset = pd.read_csv(csv_file, header=0,
                              index_col=0, encoding="TIS-620")

        if m_avr == '3-DAY-All-':
            locals()[name_locals] = mavr_dataset(dataset,3,1,'mean')
        elif m_avr == '7-DAY-All':
            locals()[name_locals] = mavr_dataset(dataset,7,1,'mean')
        elif m_avr == '14-DAY-All':
            locals()[name_locals] = mavr_dataset(dataset,14,1,'mean')
        elif m_avr == '3-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,3,3,'sum')
        elif m_avr == '7-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,7,7,'sum')
        elif m_avr == '14-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,14,14,'sum')
        else :
            locals()[name_locals] = dataset
            # print(f'Dataframe name_station: {st+1 , name_input}')
        print('wait......')
        del dataset
        clear_output(wait=True)

    date_start = y_1 + '-01' + '-01'
    date_stop = y_2 + '-12' + '-31'

#---------------------------------------------------------------------------------------------------------------------------------------------------#
    if st_BPH != 'ALL' :
        # file_name = df_st['nameEng'][data_list_st_num[st_BPH]]
        file_name = st_BPH
        locals_input = 'stN_' + file_name
        print(locals_input)
        dataset_st = locals()[locals_input].loc[date_start:date_stop]
        frames_st = dataset_st
    else:
        m = 0
        for j in range(len(data_list_st_num)):
            # for j in range(df_st.shape[0]):
            # file_name = df_st['nameEng'][j]
            file_name = df_st['nameEng'][data_list_st_num[j]]
            locals_input = 'stN_' + file_name
            print(locals_input)
            dataset_st = locals()[locals_input].loc[date_start:date_stop]
            clear_output(wait=True)
            if m == 0:
                frames_st = dataset_st
                m = m+1
                print(m)
            else:
                frames_st = [frames_st, dataset_st]
                frames_st = pd.concat(frames_st)

    # dataset    
    frames = frames_st
    return frames
#---------------------------------------------------------------------------------------------------------------------------------------------------#

#################-- Drop Colum  --#################
def drop_col(df_drop,drop = ['address']):
    for j in range(len(drop)):
        df_drop = df_drop.drop(drop[j], axis=1)
    return df_drop

#################--      Plot        --#################
def plot_data(frames_train,plot_cols,df_name,start='2015',end='2017',st = 'ALL'):
    #ตรวจสอบข้อมูล dataset 
    if st == 'ALL':
        df_plot = frames_train[plot_cols]
    else:
        df_plot = frames_train[plot_cols].loc[start:end]
    
    plt.figure()    
    # df_plot.plot(lw=1,grid=True,figsize=(13,30),subplots=True)
    # df_plot.plot(lw=1,grid=True,subplots=True)
    # df_plot.plot(marker='.',grid=True,linestyle = 'solid',subplots=True)
    df_plot.plot(marker='.',grid=True,linestyle = 'solid')
    plt.xlabel('Date time-'+ df_name)
    plt.legend()
    # plt.show()   

#################--   get list of folders in directory   --#################
dir_path = cwd + "/Export_lstm/model/"
def get_list_folder():
    folder_list = os.listdir(dir_path)
    return folder_list

def get_file_model(file_name):
    txt = dir_path+file_name+"/Training_model_data_discription.txt"
    string_data = open(txt,"r").read()
    list_txt = list(string_data.split("\n"))
    return list_txt
# Out:
# All low RiceCenter 34 station

# %%
#########################################-- Dashboard Input Data--#########################################
ALL = 'ALL'

def unique_sorted_values_plus_ALL(array):
    unique = array.unique().tolist()
    unique.sort()
    unique.insert(0, ALL)
    return unique

#################-- DataFrame station --#################
output_df_st = widgets.Output()
def dropdown_station_eventhandler(change):
    output_df_st.clear_output()
    with output_df_st:  
        if (change.new == ALL):
            display(df_st)
        else:
            display(df_st[df_st.nameEng == change.new])

#################-- DataFrame station --#################
output_df_st_predict = widgets.Output()
def dropdown_station_predict_eventhandler(change):
    output_df_st_predict.clear_output()
    with output_df_st_predict:  
        if (change.new == ALL):
            display(df_st)
        else:
            display(df_st[df_st.nameEng == change.new])

#################-- load data  --#################


output_df_train = widgets.Output()
output_df_val = widgets.Output()
output_df_test = widgets.Output()
output_df_col = widgets.Output()
def clicked_load(b):
    global df_out_train
    global df_out_val
    global df_out_test
    global selected_data 
    output_df_train.clear_output()
    output_df_val.clear_output()
    output_df_test.clear_output()
    output_df_col.clear_output()
    with output_df_train:
        df_out_train = creat_dataset(dropdown_name_st.value,dropdown_year_train1.value,dropdown_year_train2.value,dropdown_sampling_data.value)
        display(df_out_train)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_train1.value,dropdown_year_train2.value,dropdown_sampling_data.value))
    with output_df_val:
        df_out_val = creat_dataset(dropdown_name_st.value,dropdown_year_val1.value,dropdown_year_val2.value,dropdown_sampling_data.value)
        display(df_out_val)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_val1.value,dropdown_year_val2.value,dropdown_sampling_data.value))
    with output_df_test:
        df_out_test = creat_dataset(dropdown_name_st.value,dropdown_year_test1.value,dropdown_year_test2.value,dropdown_sampling_data.value)
        display(df_out_test)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_test1.value,dropdown_year_test2.value,dropdown_sampling_data.value))
    with output_df_col:
        checkbox_objects = []
        # global selected_data
        data = sorted(set(chek_list(df_out_train)),reverse=True)     
        names = []
        for key in data:
                checkbox_objects.append(widgets.Checkbox(value=True, description=key))
                names.append(key)
 
        arg_dict = {names[i]: checkbox for i, checkbox in enumerate(checkbox_objects)}
        ui = widgets.HBox(children=checkbox_objects)
        display(ui)
             
        selected_data = []
        def select_data(**kwargs):
            selected_data.clear()
            for key in kwargs:
                if kwargs[key] is True:
                    selected_data.append(key)
            print(selected_data)

        widgets.interactive_output(select_data, arg_dict)
    
 
#################-- Export data  --#################
df_train = widgets.Output()
df_val = widgets.Output()
df_test = widgets.Output()
def clicked_export(b):
    df_train.clear_output()
    df_val.clear_output()
    df_test.clear_output()
    global frames_train
    global frames_val
    global frames_test
    with df_train:
        frames_train = drop_col(df_out_train,selected_data) 
        display(frames_train)
    with df_val:
        frames_val = drop_col(df_out_val,selected_data) 
        display(frames_val)  
    with df_test:
        frames_test = drop_col(df_out_test,selected_data) 
        display(frames_test)  

def chek_list(df_ch):
        data_col = set(df_ch.columns)
        return data_col      

#################----------------------------- DashBoard display ----------------------------------#################
dropdown_name_st = widgets.Dropdown(options = unique_sorted_values_plus_ALL(df_st.nameEng),description='station :')
dropdown_sampling_data = widgets.Dropdown(options = ['All','3-DAY-All','7-DAY-All','14-DAY-All','3-DAY-Sampling','7-DAY-Sampling','14-DAY-Sampling'],valure = 'All-DAY',description='Sampling :')
dropdown_year_train1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],description='Year-train :')
dropdown_year_train2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2017')
dropdown_year_val1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2018',description='Year-val :')
dropdown_year_val2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2018')
dropdown_year_test1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2019',description='Year-test :')
dropdown_year_test2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2019')


button_download = widgets.Button(description='load data',disabled=False,button_style='success',tooltip='Click me',icon='check')
button_export = widgets.Button(description='export dataset',disabled=False,button_style='success',tooltip='Click me',icon='check')

button_download.on_click(clicked_load)
button_export.on_click(clicked_export)

dropdown_name_st.observe(dropdown_station_eventhandler, names='value')


item_layout = widgets.Layout(margin='0 0 15px 0')
input_widgets_row1 = widgets.HBox([dropdown_name_st,dropdown_year_train1,dropdown_year_train2,dropdown_year_val1,dropdown_year_val2,dropdown_year_test1,dropdown_year_test2],layout = item_layout)
input_widgets_row2 = widgets.HBox([dropdown_sampling_data,button_download,button_export],layout = item_layout)

tab_dataset = widgets.Tab([output_df_st,output_df_train,output_df_val,output_df_test,output_df_col,df_train,df_val,df_test])
tab_dataset.set_title(0, 'Dataset station')
tab_dataset.set_title(1, 'train-data')
tab_dataset.set_title(2, 'validation-data')
tab_dataset.set_title(3, 'test-data')
tab_dataset.set_title(4, 'Drop-data')
tab_dataset.set_title(5, 'Dataset-train')
tab_dataset.set_title(6, 'Dataset-validation')
tab_dataset.set_title(7, 'Dataset-test')
dashboard_dataset = widgets.VBox([input_widgets_row1,input_widgets_row2])
display(dashboard_dataset)
display(tab_dataset)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='station :', options=('ALL', 'Chachoengsao Rice research Ce…
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), _titles={'0': '…

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
def plot_data(frames_train,df_name):
    #ตรวจสอบข้อมูล dataset 
    plt.figure()
    df_plot = frames_train
    df_plot.plot(lw=1,grid=True,subplots=True)
    plt.xlabel('Date time-'+ df_name)
    plt.legend()
    # plt.show()

# %%
plot_data(frames_train,'test')

values_train = frames_train.values    
n_features = frames_train.shape[1]

values_validation = frames_val.values
values_predict = frames_test.values

df = frames_test.reset_index()
date_time_predict = pd.to_datetime(df.pop('date'))

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder


n_day = 7
n_out = 3

#train data
# ensure all data is float
values = values_train.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)
# print(reframed.shape)
# print(reframed.head())

# predict datasets
values = reframed.values
train = values

#input 
n_obs = n_day * n_features
# train_X, train_y = train[:, :n_obs], train[:, -n_features]
train_X, train_y = train[:, :n_obs], train[:, -1]
print(train_X.shape, len(train_X), train_y.shape)  #for train


# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_day, n_features))
print(train_X.shape, train_y.shape)

#validation data
# ensure all data is float
values = values_validation.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)

# predict datasets
values = reframed.values
test = values

#output 
n_obs = n_day * n_features
# test_X, test_y = test[:, :n_obs], test[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(test_X.shape, len(test_X), test_y.shape)  #for train

# reshape input to be 3D [samples, timesteps, features]
test_X = test_X.reshape((test_X.shape[0], n_day, n_features))
print(test_X.shape, test_y.shape)


##------train-----##
model = tf.keras.models.Sequential([
                  # Shape [batch, time, features] => [batch, time, lstm_units]
                  keras.layers.LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2]),activation='relu'),
                  keras.layers.Dense(units=1)
    ])
# model = tf.keras.models.Sequential([
#                   # Shape [batch, time, features] => [batch, time, lstm_units]
#                   keras.layers.LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2]),return_sequences=True,activation='relu'),
#                 #   keras.layers.BatchNormalization(),
#                 #   keras.layers.Dropout(0.2),
#                 #   keras.layers.LSTM(50, return_sequences=True, activation='relu'),
#                 #   keras.layers.BatchNormalization(),
#                 #   keras.layers.Dropout(0.2),
#                   keras.layers.LSTM(50, activation='relu'),
#                 #   keras.layers.BatchNormalization(),
#                 #   keras.layers.Dropout(0.2),
#                   keras.layers.Dense(units=1)
#             ])            
Optimizer = tf.keras.optimizers.Adam(0.0001)
model.compile(Optimizer, loss='mae', metrics=['accuracy'])
# model.summary()

# fit network
Epochs = 1500
batch_size = 128
history = model.fit(train_X, train_y, 
                    epochs=Epochs, 
                    batch_size=batch_size, 
                    validation_data=(test_X, test_y), 
                    verbose=1, 
                    # callbacks=[cp_callback,es_callback], 
                    shuffle=False)

# plot history
from matplotlib import pyplot as plt
def plot_loss(history):
    plt.figure()
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='val')
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)
#     plt.show()

plot_loss(history)
# Out:
# (1087, 49) 1087 (1087,)
# (1087, 7, 7) (1087,)
# (356, 49) 356 (356,)
# (356, 7, 7) (356,)
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/1500
# 9/9 [==============================] - 1s 25ms/step - loss: 0.0456 - accuracy: 0.0736 - val_loss: 0.0756 - val_accuracy: 0.0225
# Epoch 2/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0440 - accuracy: 0.0736 - val_loss: 0.0750 - val_accuracy: 0.0225
# Epoch 3/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0413 - accuracy: 0.0736 - val_loss: 0.0749 - val_accuracy: 0.0225
# Epoch 4/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0394 - accuracy: 0.0736 - val_loss: 0.0722 - val_accuracy: 0.0225
# Epoch 5/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0381 - accuracy: 0.0736 - val_loss: 0.0713 - val_accuracy: 0.0225
# Epoch 6/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0370 - accuracy: 0.0736 - val_loss: 0.0710 - val_accuracy: 0.0225
# Epoch 7/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0361 - accuracy: 0.0736 - val_loss: 0.0697 - val_accuracy: 0.0225
# Epoch 8/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0356 - accuracy: 0.0736 - val_loss: 0.0692 - val_accuracy: 0.0225
# Epoch 9/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0350 - accuracy: 0.0736 - val_loss: 0.0682 - val_accuracy: 0.0225
# Epoch 10/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0346 - accuracy: 0.0736 - val_loss: 0.0677 - val_accuracy: 0.0225
# Epoch 11/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0342 - accuracy: 0.0736 - val_loss: 0.0673 - val_accuracy: 0.0225
# Epoch 12/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0339 - accuracy: 0.0736 - val_loss: 0.0668 - val_accuracy: 0.0225
# Epoch 13/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0335 - accuracy: 0.0736 - val_loss: 0.0663 - val_accuracy: 0.0225
# Epoch 14/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0333 - accuracy: 0.0736 - val_loss: 0.0657 - val_accuracy: 0.0225
# Epoch 15/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0330 - accuracy: 0.0736 - val_loss: 0.0653 - val_accuracy: 0.0225
# Epoch 16/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0327 - accuracy: 0.0736 - val_loss: 0.0649 - val_accuracy: 0.0225
# Epoch 17/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0324 - accuracy: 0.0736 - val_loss: 0.0643 - val_accuracy: 0.0225
# Epoch 18/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0323 - accuracy: 0.0736 - val_loss: 0.0639 - val_accuracy: 0.0225
# Epoch 19/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0320 - accuracy: 0.0736 - val_loss: 0.0635 - val_accuracy: 0.0225
# Epoch 20/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0317 - accuracy: 0.0736 - val_loss: 0.0629 - val_accuracy: 0.0225
# Epoch 21/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0316 - accuracy: 0.0736 - val_loss: 0.0627 - val_accuracy: 0.0225
# Epoch 22/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0313 - accuracy: 0.0736 - val_loss: 0.0621 - val_accuracy: 0.0225
# Epoch 23/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0311 - accuracy: 0.0736 - val_loss: 0.0619 - val_accuracy: 0.0225
# Epoch 24/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0308 - accuracy: 0.0736 - val_loss: 0.0614 - val_accuracy: 0.0225
# Epoch 25/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0305 - accuracy: 0.0736 - val_loss: 0.0610 - val_accuracy: 0.0225
# Epoch 26/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0303 - accuracy: 0.0736 - val_loss: 0.0605 - val_accuracy: 0.0225
# Epoch 27/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0300 - accuracy: 0.0736 - val_loss: 0.0600 - val_accuracy: 0.0225
# Epoch 28/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0299 - accuracy: 0.0736 - val_loss: 0.0597 - val_accuracy: 0.0225
# Epoch 29/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0296 - accuracy: 0.0736 - val_loss: 0.0593 - val_accuracy: 0.0225
# Epoch 30/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0293 - accuracy: 0.0736 - val_loss: 0.0589 - val_accuracy: 0.0225
# Epoch 31/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0291 - accuracy: 0.0736 - val_loss: 0.0584 - val_accuracy: 0.0225
# Epoch 32/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0291 - accuracy: 0.0736 - val_loss: 0.0582 - val_accuracy: 0.0225
# Epoch 33/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0288 - accuracy: 0.0736 - val_loss: 0.0580 - val_accuracy: 0.0225
# Epoch 34/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0285 - accuracy: 0.0736 - val_loss: 0.0574 - val_accuracy: 0.0225
# Epoch 35/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0285 - accuracy: 0.0736 - val_loss: 0.0570 - val_accuracy: 0.0225
# Epoch 36/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0284 - accuracy: 0.0736 - val_loss: 0.0567 - val_accuracy: 0.0225
# Epoch 37/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0283 - accuracy: 0.0736 - val_loss: 0.0567 - val_accuracy: 0.0225
# Epoch 38/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0279 - accuracy: 0.0736 - val_loss: 0.0564 - val_accuracy: 0.0225
# Epoch 39/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0277 - accuracy: 0.0736 - val_loss: 0.0557 - val_accuracy: 0.0225
# Epoch 40/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0278 - accuracy: 0.0736 - val_loss: 0.0553 - val_accuracy: 0.0225
# Epoch 41/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0278 - accuracy: 0.0736 - val_loss: 0.0553 - val_accuracy: 0.0225
# Epoch 42/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0274 - accuracy: 0.0736 - val_loss: 0.0553 - val_accuracy: 0.0225
# Epoch 43/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0271 - accuracy: 0.0736 - val_loss: 0.0547 - val_accuracy: 0.0225
# Epoch 44/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0271 - accuracy: 0.0736 - val_loss: 0.0540 - val_accuracy: 0.0225
# Epoch 45/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0275 - accuracy: 0.0736 - val_loss: 0.0542 - val_accuracy: 0.0225
# Epoch 46/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0269 - accuracy: 0.0736 - val_loss: 0.0542 - val_accuracy: 0.0225
# Epoch 47/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0267 - accuracy: 0.0736 - val_loss: 0.0537 - val_accuracy: 0.0225
# Epoch 48/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0266 - accuracy: 0.0736 - val_loss: 0.0530 - val_accuracy: 0.0225
# Epoch 49/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0269 - accuracy: 0.0736 - val_loss: 0.0530 - val_accuracy: 0.0225
# Epoch 50/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0266 - accuracy: 0.0736 - val_loss: 0.0531 - val_accuracy: 0.0225
# Epoch 51/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0262 - accuracy: 0.0736 - val_loss: 0.0528 - val_accuracy: 0.0225
# Epoch 52/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0260 - accuracy: 0.0736 - val_loss: 0.0521 - val_accuracy: 0.0225
# Epoch 53/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0261 - accuracy: 0.0736 - val_loss: 0.0516 - val_accuracy: 0.0225
# Epoch 54/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0267 - accuracy: 0.0736 - val_loss: 0.0520 - val_accuracy: 0.0225
# Epoch 55/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0259 - accuracy: 0.0736 - val_loss: 0.0521 - val_accuracy: 0.0225
# Epoch 56/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0256 - accuracy: 0.0736 - val_loss: 0.0512 - val_accuracy: 0.0225
# Epoch 57/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0255 - accuracy: 0.0736 - val_loss: 0.0505 - val_accuracy: 0.0225
# Epoch 58/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0258 - accuracy: 0.0736 - val_loss: 0.0504 - val_accuracy: 0.0225
# Epoch 59/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0261 - accuracy: 0.0736 - val_loss: 0.0508 - val_accuracy: 0.0225
# Epoch 60/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0253 - accuracy: 0.0736 - val_loss: 0.0508 - val_accuracy: 0.0225
# Epoch 61/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0251 - accuracy: 0.0736 - val_loss: 0.0498 - val_accuracy: 0.0225
# Epoch 62/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0251 - accuracy: 0.0736 - val_loss: 0.0492 - val_accuracy: 0.0225
# Epoch 63/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0257 - accuracy: 0.0736 - val_loss: 0.0493 - val_accuracy: 0.0225
# Epoch 64/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0252 - accuracy: 0.0736 - val_loss: 0.0495 - val_accuracy: 0.0225
# Epoch 65/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0247 - accuracy: 0.0736 - val_loss: 0.0494 - val_accuracy: 0.0225
# Epoch 66/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0245 - accuracy: 0.0736 - val_loss: 0.0486 - val_accuracy: 0.0225
# Epoch 67/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0246 - accuracy: 0.0736 - val_loss: 0.0482 - val_accuracy: 0.0225
# Epoch 68/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0253 - accuracy: 0.0736 - val_loss: 0.0484 - val_accuracy: 0.0225
# Epoch 69/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0244 - accuracy: 0.0736 - val_loss: 0.0484 - val_accuracy: 0.0225
# Epoch 70/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0241 - accuracy: 0.0736 - val_loss: 0.0480 - val_accuracy: 0.0225
# Epoch 71/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0240 - accuracy: 0.0736 - val_loss: 0.0475 - val_accuracy: 0.0225
# Epoch 72/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0241 - accuracy: 0.0736 - val_loss: 0.0474 - val_accuracy: 0.0225
# Epoch 73/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0246 - accuracy: 0.0736 - val_loss: 0.0475 - val_accuracy: 0.0225
# Epoch 74/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0239 - accuracy: 0.0736 - val_loss: 0.0476 - val_accuracy: 0.0225
# Epoch 75/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0235 - accuracy: 0.0736 - val_loss: 0.0474 - val_accuracy: 0.0225
# Epoch 76/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0234 - accuracy: 0.0736 - val_loss: 0.0469 - val_accuracy: 0.0225
# Epoch 77/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0233 - accuracy: 0.0736 - val_loss: 0.0467 - val_accuracy: 0.0225
# Epoch 78/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0240 - accuracy: 0.0736 - val_loss: 0.0467 - val_accuracy: 0.0225
# Epoch 79/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0236 - accuracy: 0.0736 - val_loss: 0.0468 - val_accuracy: 0.0225
# Epoch 80/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0230 - accuracy: 0.0736 - val_loss: 0.0469 - val_accuracy: 0.0225
# Epoch 81/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0229 - accuracy: 0.0736 - val_loss: 0.0465 - val_accuracy: 0.0225
# Epoch 82/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0227 - accuracy: 0.0736 - val_loss: 0.0461 - val_accuracy: 0.0225
# Epoch 83/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0227 - accuracy: 0.0736 - val_loss: 0.0460 - val_accuracy: 0.0225
# Epoch 84/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0234 - accuracy: 0.0736 - val_loss: 0.0460 - val_accuracy: 0.0225
# Epoch 85/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0229 - accuracy: 0.0736 - val_loss: 0.0461 - val_accuracy: 0.0225
# Epoch 86/1500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0224 - accuracy: 0.0736 - val_loss: 0.0461 - val_accuracy: 0.0225
# Epoch 87/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0223 - accuracy: 0.0736 - val_loss: 0.0459 - val_accuracy: 0.0225
# Epoch 88/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0222 - accuracy: 0.0736 - val_loss: 0.0457 - val_accuracy: 0.0225
# Epoch 89/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0221 - accuracy: 0.0736 - val_loss: 0.0454 - val_accuracy: 0.0225
# Epoch 90/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0222 - accuracy: 0.0736 - val_loss: 0.0454 - val_accuracy: 0.0225
# Epoch 91/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0229 - accuracy: 0.0736 - val_loss: 0.0454 - val_accuracy: 0.0225
# Epoch 92/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0228 - accuracy: 0.0736 - val_loss: 0.0455 - val_accuracy: 0.0225
# Epoch 93/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0222 - accuracy: 0.0736 - val_loss: 0.0455 - val_accuracy: 0.0225
# Epoch 94/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0221 - accuracy: 0.0736 - val_loss: 0.0455 - val_accuracy: 0.0225
# Epoch 95/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0221 - accuracy: 0.0736 - val_loss: 0.0454 - val_accuracy: 0.0225
# Epoch 96/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0220 - accuracy: 0.0736 - val_loss: 0.0452 - val_accuracy: 0.0225
# Epoch 97/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0219 - accuracy: 0.0736 - val_loss: 0.0450 - val_accuracy: 0.0225
# Epoch 98/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0219 - accuracy: 0.0736 - val_loss: 0.0450 - val_accuracy: 0.0225
# Epoch 99/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0221 - accuracy: 0.0736 - val_loss: 0.0451 - val_accuracy: 0.0225
# Epoch 100/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0225 - accuracy: 0.0736 - val_loss: 0.0451 - val_accuracy: 0.0225
# Epoch 101/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0225 - accuracy: 0.0736 - val_loss: 0.0451 - val_accuracy: 0.0225
# Epoch 102/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0221 - accuracy: 0.0736 - val_loss: 0.0451 - val_accuracy: 0.0225
# Epoch 103/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0220 - accuracy: 0.0736 - val_loss: 0.0452 - val_accuracy: 0.0225
# Epoch 104/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0220 - accuracy: 0.0736 - val_loss: 0.0452 - val_accuracy: 0.0225
# Epoch 105/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0220 - accuracy: 0.0736 - val_loss: 0.0452 - val_accuracy: 0.0225
# Epoch 106/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0219 - accuracy: 0.0736 - val_loss: 0.0449 - val_accuracy: 0.0225
# Epoch 107/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0217 - accuracy: 0.0736 - val_loss: 0.0448 - val_accuracy: 0.0225
# Epoch 108/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0217 - accuracy: 0.0736 - val_loss: 0.0447 - val_accuracy: 0.0225
# Epoch 109/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0218 - accuracy: 0.0736 - val_loss: 0.0447 - val_accuracy: 0.0225
# Epoch 110/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0221 - accuracy: 0.0736 - val_loss: 0.0448 - val_accuracy: 0.0225
# Epoch 111/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0225 - accuracy: 0.0736 - val_loss: 0.0448 - val_accuracy: 0.0225
# Epoch 112/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0222 - accuracy: 0.0736 - val_loss: 0.0448 - val_accuracy: 0.0225
# Epoch 113/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0219 - accuracy: 0.0736 - val_loss: 0.0448 - val_accuracy: 0.0225
# Epoch 114/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0218 - accuracy: 0.0736 - val_loss: 0.0449 - val_accuracy: 0.0225
# Epoch 115/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0218 - accuracy: 0.0736 - val_loss: 0.0449 - val_accuracy: 0.0225
# Epoch 116/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0218 - accuracy: 0.0736 - val_loss: 0.0449 - val_accuracy: 0.0225
# Epoch 117/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0218 - accuracy: 0.0736 - val_loss: 0.0448 - val_accuracy: 0.0225
# Epoch 118/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0217 - accuracy: 0.0736 - val_loss: 0.0446 - val_accuracy: 0.0225
# Epoch 119/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0444 - val_accuracy: 0.0225
# Epoch 120/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0444 - val_accuracy: 0.0225
# Epoch 121/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0218 - accuracy: 0.0736 - val_loss: 0.0445 - val_accuracy: 0.0225
# Epoch 122/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0223 - accuracy: 0.0736 - val_loss: 0.0445 - val_accuracy: 0.0225
# Epoch 123/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0223 - accuracy: 0.0736 - val_loss: 0.0445 - val_accuracy: 0.0225
# Epoch 124/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0218 - accuracy: 0.0736 - val_loss: 0.0445 - val_accuracy: 0.0225
# Epoch 125/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0445 - val_accuracy: 0.0225
# Epoch 126/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0445 - val_accuracy: 0.0225
# Epoch 127/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0445 - val_accuracy: 0.0225
# Epoch 128/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0445 - val_accuracy: 0.0225
# Epoch 129/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0444 - val_accuracy: 0.0225
# Epoch 130/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0442 - val_accuracy: 0.0225
# Epoch 131/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0441 - val_accuracy: 0.0225
# Epoch 132/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0441 - val_accuracy: 0.0225
# Epoch 133/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0441 - val_accuracy: 0.0225
# Epoch 134/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0441 - val_accuracy: 0.0225
# Epoch 135/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0220 - accuracy: 0.0736 - val_loss: 0.0443 - val_accuracy: 0.0225
# Epoch 136/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0225 - accuracy: 0.0736 - val_loss: 0.0441 - val_accuracy: 0.0225
# Epoch 137/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0217 - accuracy: 0.0736 - val_loss: 0.0442 - val_accuracy: 0.0225
# Epoch 138/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0442 - val_accuracy: 0.0225
# Epoch 139/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0442 - val_accuracy: 0.0225
# Epoch 140/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0443 - val_accuracy: 0.0225
# Epoch 141/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0443 - val_accuracy: 0.0225
# Epoch 142/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0441 - val_accuracy: 0.0225
# Epoch 143/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 0.0736 - val_loss: 0.0438 - val_accuracy: 0.0225
# Epoch 144/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 0.0736 - val_loss: 0.0437 - val_accuracy: 0.0225
# Epoch 145/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 0.0736 - val_loss: 0.0437 - val_accuracy: 0.0225
# Epoch 146/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0439 - val_accuracy: 0.0225
# Epoch 147/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0220 - accuracy: 0.0736 - val_loss: 0.0439 - val_accuracy: 0.0225
# Epoch 148/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0221 - accuracy: 0.0736 - val_loss: 0.0438 - val_accuracy: 0.0225
# Epoch 149/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0217 - accuracy: 0.0736 - val_loss: 0.0438 - val_accuracy: 0.0225
# Epoch 150/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0439 - val_accuracy: 0.0225
# Epoch 151/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0440 - val_accuracy: 0.0225
# Epoch 152/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0442 - val_accuracy: 0.0225
# Epoch 153/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0441 - val_accuracy: 0.0225
# Epoch 154/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 0.0736 - val_loss: 0.0437 - val_accuracy: 0.0225
# Epoch 155/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0435 - val_accuracy: 0.0225
# Epoch 156/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0435 - val_accuracy: 0.0225
# Epoch 157/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 158/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0219 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 159/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0217 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 160/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 161/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 162/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 163/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 164/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 165/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0437 - val_accuracy: 0.0225
# Epoch 166/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0436 - val_accuracy: 0.0225
# Epoch 167/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0210 - accuracy: 0.0736 - val_loss: 0.0433 - val_accuracy: 0.0225
# Epoch 168/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0209 - accuracy: 0.0736 - val_loss: 0.0432 - val_accuracy: 0.0225
# Epoch 169/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0210 - accuracy: 0.0736 - val_loss: 0.0432 - val_accuracy: 0.0225
# Epoch 170/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0210 - accuracy: 0.0736 - val_loss: 0.0432 - val_accuracy: 0.0225
# Epoch 171/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 0.0736 - val_loss: 0.0433 - val_accuracy: 0.0225
# Epoch 172/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0434 - val_accuracy: 0.0225
# Epoch 173/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0218 - accuracy: 0.0736 - val_loss: 0.0433 - val_accuracy: 0.0225
# Epoch 174/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.0736 - val_loss: 0.0433 - val_accuracy: 0.0225
# Epoch 175/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0434 - val_accuracy: 0.0225
# Epoch 176/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0435 - val_accuracy: 0.0225
# Epoch 177/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0437 - val_accuracy: 0.0225
# Epoch 178/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0437 - val_accuracy: 0.0225
# Epoch 179/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0433 - val_accuracy: 0.0225
# Epoch 180/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0430 - val_accuracy: 0.0225
# Epoch 181/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0430 - val_accuracy: 0.0225
# Epoch 182/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0432 - val_accuracy: 0.0225
# Epoch 183/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0431 - val_accuracy: 0.0225
# Epoch 184/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 0.0736 - val_loss: 0.0431 - val_accuracy: 0.0225
# Epoch 185/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0431 - val_accuracy: 0.0225
# Epoch 186/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0209 - accuracy: 0.0736 - val_loss: 0.0430 - val_accuracy: 0.0225
# Epoch 187/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0430 - val_accuracy: 0.0225
# Epoch 188/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0431 - val_accuracy: 0.0225
# Epoch 189/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0431 - val_accuracy: 0.0225
# Epoch 190/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0430 - val_accuracy: 0.0225
# Epoch 191/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0207 - accuracy: 0.0736 - val_loss: 0.0431 - val_accuracy: 0.0225
# Epoch 192/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0207 - accuracy: 0.0736 - val_loss: 0.0431 - val_accuracy: 0.0225
# Epoch 193/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0207 - accuracy: 0.0736 - val_loss: 0.0431 - val_accuracy: 0.0225
# Epoch 194/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0429 - val_accuracy: 0.0225
# Epoch 195/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0428 - val_accuracy: 0.0225
# Epoch 196/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0427 - val_accuracy: 0.0225
# Epoch 197/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0427 - val_accuracy: 0.0225
# Epoch 198/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 199/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 200/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 201/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0428 - val_accuracy: 0.0225
# Epoch 202/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 0.0736 - val_loss: 0.0429 - val_accuracy: 0.0225
# Epoch 203/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.0736 - val_loss: 0.0427 - val_accuracy: 0.0225
# Epoch 204/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0427 - val_accuracy: 0.0225
# Epoch 205/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0209 - accuracy: 0.0736 - val_loss: 0.0429 - val_accuracy: 0.0225
# Epoch 206/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0209 - accuracy: 0.0736 - val_loss: 0.0432 - val_accuracy: 0.0225
# Epoch 207/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0432 - val_accuracy: 0.0225
# Epoch 208/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0207 - accuracy: 0.0736 - val_loss: 0.0432 - val_accuracy: 0.0225
# Epoch 209/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0428 - val_accuracy: 0.0225
# Epoch 210/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 0.0736 - val_loss: 0.0424 - val_accuracy: 0.0225
# Epoch 211/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 0.0736 - val_loss: 0.0423 - val_accuracy: 0.0225
# Epoch 212/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0205 - accuracy: 0.0736 - val_loss: 0.0424 - val_accuracy: 0.0225
# Epoch 213/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 214/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0214 - accuracy: 0.0736 - val_loss: 0.0425 - val_accuracy: 0.0225
# Epoch 215/1500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0424 - val_accuracy: 0.0225
# Epoch 216/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0207 - accuracy: 0.0736 - val_loss: 0.0425 - val_accuracy: 0.0225
# Epoch 217/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 218/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0205 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 219/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0205 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 220/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 0.0736 - val_loss: 0.0425 - val_accuracy: 0.0225
# Epoch 221/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0424 - val_accuracy: 0.0225
# Epoch 222/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0202 - accuracy: 0.0736 - val_loss: 0.0422 - val_accuracy: 0.0225
# Epoch 223/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0202 - accuracy: 0.0736 - val_loss: 0.0421 - val_accuracy: 0.0225
# Epoch 224/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0421 - val_accuracy: 0.0225
# Epoch 225/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0202 - accuracy: 0.0736 - val_loss: 0.0420 - val_accuracy: 0.0225
# Epoch 226/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0420 - val_accuracy: 0.0225
# Epoch 227/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0205 - accuracy: 0.0736 - val_loss: 0.0422 - val_accuracy: 0.0225
# Epoch 228/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0209 - accuracy: 0.0736 - val_loss: 0.0422 - val_accuracy: 0.0225
# Epoch 229/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 0.0736 - val_loss: 0.0421 - val_accuracy: 0.0225
# Epoch 230/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0206 - accuracy: 0.0736 - val_loss: 0.0421 - val_accuracy: 0.0225
# Epoch 231/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0205 - accuracy: 0.0736 - val_loss: 0.0423 - val_accuracy: 0.0225
# Epoch 232/1500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0205 - accuracy: 0.0736 - val_loss: 0.0424 - val_accuracy: 0.0225
# Epoch 233/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0204 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 234/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0426 - val_accuracy: 0.0225
# Epoch 235/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0424 - val_accuracy: 0.0225
# Epoch 236/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0420 - val_accuracy: 0.0225
# Epoch 237/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0200 - accuracy: 0.0736 - val_loss: 0.0418 - val_accuracy: 0.0225
# Epoch 238/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0200 - accuracy: 0.0736 - val_loss: 0.0417 - val_accuracy: 0.0225
# Epoch 239/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0417 - val_accuracy: 0.0225
# Epoch 240/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0417 - val_accuracy: 0.0225
# Epoch 241/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0417 - val_accuracy: 0.0225
# Epoch 242/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0418 - val_accuracy: 0.0225
# Epoch 243/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0205 - accuracy: 0.0736 - val_loss: 0.0420 - val_accuracy: 0.0225
# Epoch 244/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0211 - accuracy: 0.0736 - val_loss: 0.0417 - val_accuracy: 0.0225
# Epoch 245/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0205 - accuracy: 0.0736 - val_loss: 0.0417 - val_accuracy: 0.0225
# Epoch 246/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0419 - val_accuracy: 0.0225
# Epoch 247/1500
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0420 - val_accuracy: 0.0225
# Epoch 248/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0202 - accuracy: 0.0736 - val_loss: 0.0421 - val_accuracy: 0.0225
# Epoch 249/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0423 - val_accuracy: 0.0225
# Epoch 250/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0422 - val_accuracy: 0.0225
# Epoch 251/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0200 - accuracy: 0.0736 - val_loss: 0.0418 - val_accuracy: 0.0225
# Epoch 252/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0198 - accuracy: 0.0736 - val_loss: 0.0414 - val_accuracy: 0.0225
# Epoch 253/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0198 - accuracy: 0.0736 - val_loss: 0.0413 - val_accuracy: 0.0225
# Epoch 254/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0198 - accuracy: 0.0736 - val_loss: 0.0414 - val_accuracy: 0.0225
# Epoch 255/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0198 - accuracy: 0.0736 - val_loss: 0.0413 - val_accuracy: 0.0225
# Epoch 256/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0199 - accuracy: 0.0736 - val_loss: 0.0413 - val_accuracy: 0.0225
# Epoch 257/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0199 - accuracy: 0.0736 - val_loss: 0.0413 - val_accuracy: 0.0225
# Epoch 258/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0415 - val_accuracy: 0.0225
# Epoch 259/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 0.0736 - val_loss: 0.0415 - val_accuracy: 0.0225
# Epoch 260/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0210 - accuracy: 0.0736 - val_loss: 0.0414 - val_accuracy: 0.0225
# Epoch 261/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0203 - accuracy: 0.0736 - val_loss: 0.0419 - val_accuracy: 0.0225
# Epoch 262/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0421 - val_accuracy: 0.0225
# Epoch 263/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0421 - val_accuracy: 0.0225
# Epoch 264/1500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0199 - accuracy: 0.0736 - val_loss: 0.0418 - val_accuracy: 0.0225
# Epoch 265/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 0.0736 - val_loss: 0.0411 - val_accuracy: 0.0225
# Epoch 266/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0196 - accuracy: 0.0736 - val_loss: 0.0411 - val_accuracy: 0.0225
# Epoch 267/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 0.0736 - val_loss: 0.0410 - val_accuracy: 0.0225
# Epoch 268/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0196 - accuracy: 0.0736 - val_loss: 0.0410 - val_accuracy: 0.0225
# Epoch 269/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 0.0736 - val_loss: 0.0411 - val_accuracy: 0.0225
# Epoch 270/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0199 - accuracy: 0.0736 - val_loss: 0.0412 - val_accuracy: 0.0225
# Epoch 271/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0202 - accuracy: 0.0736 - val_loss: 0.0413 - val_accuracy: 0.0225
# Epoch 272/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0736 - val_loss: 0.0411 - val_accuracy: 0.0225
# Epoch 273/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0201 - accuracy: 0.0736 - val_loss: 0.0413 - val_accuracy: 0.0225
# Epoch 274/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0199 - accuracy: 0.0736 - val_loss: 0.0416 - val_accuracy: 0.0225
# Epoch 275/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0198 - accuracy: 0.0736 - val_loss: 0.0418 - val_accuracy: 0.0225
# Epoch 276/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0198 - accuracy: 0.0736 - val_loss: 0.0418 - val_accuracy: 0.0225
# Epoch 277/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 0.0736 - val_loss: 0.0412 - val_accuracy: 0.0225
# Epoch 278/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0194 - accuracy: 0.0736 - val_loss: 0.0408 - val_accuracy: 0.0225
# Epoch 279/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0194 - accuracy: 0.0736 - val_loss: 0.0407 - val_accuracy: 0.0225
# Epoch 280/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 0.0736 - val_loss: 0.0407 - val_accuracy: 0.0225
# Epoch 281/1500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0195 - accuracy: 0.0736 - val_loss: 0.0407 - val_accuracy: 0.0225
# Epoch 282/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 0.0736 - val_loss: 0.0407 - val_accuracy: 0.0225
# Epoch 283/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 0.0736 - val_loss: 0.0408 - val_accuracy: 0.0225
# Epoch 284/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0200 - accuracy: 0.0736 - val_loss: 0.0408 - val_accuracy: 0.0225
# Epoch 285/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 0.0736 - val_loss: 0.0407 - val_accuracy: 0.0225
# Epoch 286/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0198 - accuracy: 0.0736 - val_loss: 0.0410 - val_accuracy: 0.0225
# Epoch 287/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 0.0736 - val_loss: 0.0413 - val_accuracy: 0.0225
# Epoch 288/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0196 - accuracy: 0.0736 - val_loss: 0.0417 - val_accuracy: 0.0225
# Epoch 289/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 0.0736 - val_loss: 0.0412 - val_accuracy: 0.0225
# Epoch 290/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0194 - accuracy: 0.0736 - val_loss: 0.0406 - val_accuracy: 0.0225
# Epoch 291/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0192 - accuracy: 0.0736 - val_loss: 0.0403 - val_accuracy: 0.0225
# Epoch 292/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0194 - accuracy: 0.0736 - val_loss: 0.0404 - val_accuracy: 0.0225
# Epoch 293/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0196 - accuracy: 0.0736 - val_loss: 0.0405 - val_accuracy: 0.0225
# Epoch 294/1500
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0200 - accuracy: 0.0736 - val_loss: 0.0403 - val_accuracy: 0.0225
# Epoch 295/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 0.0736 - val_loss: 0.0403 - val_accuracy: 0.0225
# Epoch 296/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0193 - accuracy: 0.0736 - val_loss: 0.0403 - val_accuracy: 0.0225
# Epoch 297/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0192 - accuracy: 0.0736 - val_loss: 0.0402 - val_accuracy: 0.0225
# Epoch 298/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0192 - accuracy: 0.0736 - val_loss: 0.0402 - val_accuracy: 0.0225
# Epoch 299/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0192 - accuracy: 0.0736 - val_loss: 0.0402 - val_accuracy: 0.0225
# Epoch 300/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0191 - accuracy: 0.0736 - val_loss: 0.0401 - val_accuracy: 0.0225
# Epoch 301/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0191 - accuracy: 0.0736 - val_loss: 0.0401 - val_accuracy: 0.0225
# Epoch 302/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0191 - accuracy: 0.0736 - val_loss: 0.0401 - val_accuracy: 0.0225
# Epoch 303/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0191 - accuracy: 0.0736 - val_loss: 0.0400 - val_accuracy: 0.0225
# Epoch 304/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0190 - accuracy: 0.0736 - val_loss: 0.0399 - val_accuracy: 0.0225
# Epoch 305/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0190 - accuracy: 0.0736 - val_loss: 0.0400 - val_accuracy: 0.0225
# Epoch 306/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0190 - accuracy: 0.0736 - val_loss: 0.0399 - val_accuracy: 0.0225
# Epoch 307/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0190 - accuracy: 0.0736 - val_loss: 0.0399 - val_accuracy: 0.0225
# Epoch 308/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0189 - accuracy: 0.0736 - val_loss: 0.0398 - val_accuracy: 0.0225
# Epoch 309/1500
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0189 - accuracy: 0.0736 - val_loss: 0.0398 - val_accuracy: 0.0225
# Epoch 310/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0189 - accuracy: 0.0736 - val_loss: 0.0398 - val_accuracy: 0.0225
# Epoch 311/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0189 - accuracy: 0.0736 - val_loss: 0.0397 - val_accuracy: 0.0225
# Epoch 312/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.0736 - val_loss: 0.0397 - val_accuracy: 0.0225
# Epoch 313/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.0736 - val_loss: 0.0397 - val_accuracy: 0.0225
# Epoch 314/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.0736 - val_loss: 0.0397 - val_accuracy: 0.0225
# Epoch 315/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.0736 - val_loss: 0.0397 - val_accuracy: 0.0225
# Epoch 316/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.0736 - val_loss: 0.0398 - val_accuracy: 0.0225
# Epoch 317/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.0736 - val_loss: 0.0399 - val_accuracy: 0.0225
# Epoch 318/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.0736 - val_loss: 0.0404 - val_accuracy: 0.0225
# Epoch 319/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0189 - accuracy: 0.0736 - val_loss: 0.0406 - val_accuracy: 0.0225
# Epoch 320/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0190 - accuracy: 0.0736 - val_loss: 0.0402 - val_accuracy: 0.0225
# Epoch 321/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0187 - accuracy: 0.0736 - val_loss: 0.0397 - val_accuracy: 0.0225
# Epoch 322/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0185 - accuracy: 0.0736 - val_loss: 0.0392 - val_accuracy: 0.0225
# Epoch 323/1500
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0185 - accuracy: 0.0736 - val_loss: 0.0391 - val_accuracy: 0.0225
# Epoch 324/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0184 - accuracy: 0.0736 - val_loss: 0.0391 - val_accuracy: 0.0225
# Epoch 325/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0183 - accuracy: 0.0736 - val_loss: 0.0390 - val_accuracy: 0.0225
# Epoch 326/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.0736 - val_loss: 0.0391 - val_accuracy: 0.0225
# Epoch 327/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0182 - accuracy: 0.0736 - val_loss: 0.0389 - val_accuracy: 0.0225
# Epoch 328/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.0736 - val_loss: 0.0390 - val_accuracy: 0.0225
# Epoch 329/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0182 - accuracy: 0.0736 - val_loss: 0.0389 - val_accuracy: 0.0225
# Epoch 330/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.0736 - val_loss: 0.0389 - val_accuracy: 0.0225
# Epoch 331/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0182 - accuracy: 0.0736 - val_loss: 0.0388 - val_accuracy: 0.0225
# Epoch 332/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0181 - accuracy: 0.0736 - val_loss: 0.0388 - val_accuracy: 0.0225
# Epoch 333/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0181 - accuracy: 0.0736 - val_loss: 0.0387 - val_accuracy: 0.0225
# Epoch 334/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0180 - accuracy: 0.0736 - val_loss: 0.0387 - val_accuracy: 0.0225
# Epoch 335/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0180 - accuracy: 0.0736 - val_loss: 0.0386 - val_accuracy: 0.0225
# Epoch 336/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0180 - accuracy: 0.0736 - val_loss: 0.0386 - val_accuracy: 0.0225
# Epoch 337/1500
# ...
# Epoch 371/1500
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0168 - accuracy: 0.0736 - val_loss: 0.0377 - val_accuracy: 0.0225
# Epoch 372/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0169 - accuracy: 0.0736 - val_loss: 0.0377 - val_accuracy: 0.0225
# Epoch 373/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0168 - accuracy: 0.0736 - val_loss: 0.0377 - val_accuracy: 0.0225
# Epoch 374/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0168 - accuracy: 0.0736 - val_loss: 0.0377 - val_accuracy: 0.0225
# Epoch 375/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.0736 - val_loss: 0.0377 - val_accuracy: 0.0225
# Epoch 376/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.0736 - val_loss: 0.0376 - val_accuracy: 0.0225
# Epoch 377/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.0736 - val_loss: 0.0376 - val_accuracy: 0.0225
# Epoch 378/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.0736 - val_loss: 0.0376 - val_accuracy: 0.0225
# Epoch 379/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.0736 - val_loss: 0.0376 - val_accuracy: 0.0225
# Epoch 380/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0166 - accuracy: 0.0736 - val_loss: 0.0376 - val_accuracy: 0.0225
# Epoch 381/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0168 - accuracy: 0.0736 - val_loss: 0.0376 - val_accuracy: 0.0225
# Epoch 382/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.0736 - val_loss: 0.0375 - val_accuracy: 0.0225
# Epoch 383/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0166 - accuracy: 0.0736 - val_loss: 0.0375 - val_accuracy: 0.0225
# Epoch 384/1500
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0166 - accuracy: 0.0736 - val_loss: 0.0375 - val_accuracy: 0.0225
# Epoch 385/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0165 - accuracy: 0.0736 - val_loss: 0.0375 - val_accuracy: 0.0225
# Epoch 386/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0165 - accuracy: 0.0736 - val_loss: 0.0375 - val_accuracy: 0.0225
# Epoch 387/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0166 - accuracy: 0.0736 - val_loss: 0.0374 - val_accuracy: 0.0225
# Epoch 388/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0375 - val_accuracy: 0.0225
# Epoch 389/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0165 - accuracy: 0.0736 - val_loss: 0.0374 - val_accuracy: 0.0225
# Epoch 390/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0374 - val_accuracy: 0.0225
# Epoch 391/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0374 - val_accuracy: 0.0225
# Epoch 392/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0374 - val_accuracy: 0.0225
# Epoch 393/1500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0165 - accuracy: 0.0736 - val_loss: 0.0373 - val_accuracy: 0.0225
# Epoch 394/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0374 - val_accuracy: 0.0225
# Epoch 395/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0165 - accuracy: 0.0736 - val_loss: 0.0373 - val_accuracy: 0.0225
# Epoch 396/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0163 - accuracy: 0.0736 - val_loss: 0.0373 - val_accuracy: 0.0225
# Epoch 397/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0373 - val_accuracy: 0.0225
# Epoch 398/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.0736 - val_loss: 0.0373 - val_accuracy: 0.0225
# Epoch 399/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0372 - val_accuracy: 0.0225
# Epoch 400/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.0736 - val_loss: 0.0373 - val_accuracy: 0.0225
# Epoch 401/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.0736 - val_loss: 0.0372 - val_accuracy: 0.0225
# Epoch 402/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0373 - val_accuracy: 0.0225
# Epoch 403/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0371 - val_accuracy: 0.0225
# Epoch 404/1500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0373 - val_accuracy: 0.0225
# Epoch 405/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0165 - accuracy: 0.0736 - val_loss: 0.0372 - val_accuracy: 0.0225
# Epoch 406/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.0736 - val_loss: 0.0372 - val_accuracy: 0.0225
# Epoch 407/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.0736 - val_loss: 0.0371 - val_accuracy: 0.0225
# Epoch 408/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0371 - val_accuracy: 0.0225
# Epoch 409/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0372 - val_accuracy: 0.0225
# Epoch 410/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0371 - val_accuracy: 0.0225
# Epoch 411/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0371 - val_accuracy: 0.0225
# Epoch 412/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0371 - val_accuracy: 0.0225
# Epoch 413/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.0736 - val_loss: 0.0371 - val_accuracy: 0.0225
# Epoch 414/1500
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0161 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 415/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 416/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 417/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 418/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0160 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 419/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 420/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 421/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 422/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.0736 - val_loss: 0.0369 - val_accuracy: 0.0225
# Epoch 423/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 0.0736 - val_loss: 0.0369 - val_accuracy: 0.0225
# Epoch 424/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0159 - accuracy: 0.0736 - val_loss: 0.0369 - val_accuracy: 0.0225
# Epoch 425/1500
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0159 - accuracy: 0.0736 - val_loss: 0.0369 - val_accuracy: 0.0225
# Epoch 426/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.0736 - val_loss: 0.0368 - val_accuracy: 0.0225
# Epoch 427/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 428/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0159 - accuracy: 0.0736 - val_loss: 0.0369 - val_accuracy: 0.0225
# Epoch 429/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0159 - accuracy: 0.0736 - val_loss: 0.0368 - val_accuracy: 0.0225
# Epoch 430/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 431/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.0736 - val_loss: 0.0368 - val_accuracy: 0.0225
# Epoch 432/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0159 - accuracy: 0.0736 - val_loss: 0.0369 - val_accuracy: 0.0225
# Epoch 433/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 434/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 435/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 436/1500
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0164 - accuracy: 0.0736 - val_loss: 0.0370 - val_accuracy: 0.0225
# Epoch 437/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0171 - accuracy: 0.0736 - val_loss: 0.0377 - val_accuracy: 0.0225
# Epoch 438/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0171 - accuracy: 0.0736 - val_loss: 0.0392 - val_accuracy: 0.0225
# Epoch 439/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.0736 - val_loss: 0.0369 - val_accuracy: 0.0225
# Epoch 440/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0366 - val_accuracy: 0.0225
# Epoch 441/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0158 - accuracy: 0.0736 - val_loss: 0.0365 - val_accuracy: 0.0225
# Epoch 442/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 0.0736 - val_loss: 0.0367 - val_accuracy: 0.0225
# Epoch 443/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0157 - accuracy: 0.0736 - val_loss: 0.0366 - val_accuracy: 0.0225
# Epoch 444/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 0.0736 - val_loss: 0.0368 - val_accuracy: 0.0225
# Epoch 445/1500
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0158 - accuracy: 0.0736 - val_loss: 0.0367 - val_accuracy: 0.0225
# Epoch 446/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0158 - accuracy: 0.0736 - val_loss: 0.0366 - val_accuracy: 0.0225
# Epoch 447/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0161 - accuracy: 0.0736 - val_loss: 0.0366 - val_accuracy: 0.0225
# Epoch 448/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.0736 - val_loss: 0.0369 - val_accuracy: 0.0225
# Epoch 449/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.0736 - val_loss: 0.0383 - val_accuracy: 0.0225
# Epoch 450/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0168 - accuracy: 0.0736 - val_loss: 0.0385 - val_accuracy: 0.0225
# Epoch 451/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0172 - accuracy: 0.0736 - val_loss: 0.0367 - val_accuracy: 0.0225
# Epoch 452/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0158 - accuracy: 0.0736 - val_loss: 0.0364 - val_accuracy: 0.0225
# Epoch 453/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 0.0736 - val_loss: 0.0364 - val_accuracy: 0.0225
# Epoch 454/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 0.0736 - val_loss: 0.0366 - val_accuracy: 0.0225
# Epoch 455/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 0.0736 - val_loss: 0.0365 - val_accuracy: 0.0225
# Epoch 456/1500
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0154 - accuracy: 0.0736 - val_loss: 0.0365 - val_accuracy: 0.0225
# Epoch 457/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0154 - accuracy: 0.0736 - val_loss: 0.0365 - val_accuracy: 0.0225
# Epoch 458/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0155 - accuracy: 0.0736 - val_loss: 0.0365 - val_accuracy: 0.0225
# Epoch 459/1500
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0155 - accuracy: 0.0736 - val_loss: 0.0364 - val_accuracy: 0.0225
# Epoch 460/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0155 - accuracy: 0.0736 - val_loss: 0.0365 - val_accuracy: 0.0225
# Epoch 461/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 0.0736 - val_loss: 0.0364 - val_accuracy: 0.0225
# Epoch 462/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 0.0736 - val_loss: 0.0365 - val_accuracy: 0.0225
# Epoch 463/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 0.0736 - val_loss: 0.0365 - val_accuracy: 0.0225
# Epoch 464/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0157 - accuracy: 0.0736 - val_loss: 0.0368 - val_accuracy: 0.0225
# Epoch 465/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0159 - accuracy: 0.0736 - val_loss: 0.0383 - val_accuracy: 0.0225
# Epoch 466/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0168 - accuracy: 0.0736 - val_loss: 0.0379 - val_accuracy: 0.0225
# Epoch 467/1500
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0168 - accuracy: 0.0736 - val_loss: 0.0366 - val_accuracy: 0.0225
# Epoch 468/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0157 - accuracy: 0.0736 - val_loss: 0.0363 - val_accuracy: 0.0225
# Epoch 469/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0153 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 470/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 0.0736 - val_loss: 0.0364 - val_accuracy: 0.0225
# Epoch 471/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 0.0736 - val_loss: 0.0363 - val_accuracy: 0.0225
# Epoch 472/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 0.0736 - val_loss: 0.0364 - val_accuracy: 0.0225
# Epoch 473/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 0.0736 - val_loss: 0.0363 - val_accuracy: 0.0225
# Epoch 474/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 475/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 476/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 477/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 478/1500
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0151 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 479/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0150 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 480/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0151 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 481/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 0.0736 - val_loss: 0.0362 - val_accuracy: 0.0225
# Epoch 482/1500
# 1/9 [==>...........................] - ETA: 0s - loss: 9.4863e-04 - accuracy: 0.0312

# %%
# ensure all data is float
values = values_predict.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
    
# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)
# print(reframed.shape)
# print(reframed.head())
    
# predict datasets
values = reframed.values
# n_train_day = int(values.shape[0]*0.9)
# train = values[:n_train_day, :]
test = values
    
# predict into input and outputs
n_obs = n_day * n_features
# test_X, test_y = test[:, :n_obs], test[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(test_X.shape, len(test_X), test_y.shape)
    
# reshape input to be 3D [samples, timesteps, features]
test_X = test_X.reshape((test_X.shape[0], n_day, n_features))
print(test_X.shape, test_y.shape)
    
# # make a prediction
yhat = model.predict(test_X,verbose=0)
test_X_reshape = test_X.reshape((test_X.shape[0], n_day*n_features)) 

from cProfile import label
from numpy import concatenate

# invert scaling for forecast
# inv_yhat = concatenate((yhat, test_X[:, -29:]), axis=1)
inv_yhat = concatenate((test_X_reshape[:, :(n_features-1)], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y_reshape = test_y.reshape((len(test_y), 1))
# inv_y = concatenate((test_y, test_X[:, -29:]), axis=1)
inv_y = concatenate((test_X_reshape[:, :(n_features-1)], test_y_reshape), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]

# calculate RMSE
m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(inv_y, inv_yhat)
rmse = m.result().numpy()
print('RMSE: %.3f' % rmse)
# Out:
# (356, 49) 356 (356,)
# (356, 7, 7) (356,)
# RMSE: 62.412

# %%
strings = list(frames_test.columns)
textstr = '\n'.join(strings)

fig, ax = plt.subplots()

ax.plot(date_time_predict[n_day+n_out-1:],inv_y[:],label='actual')
ax.plot(date_time_predict[n_day+n_out-1:],inv_yhat[:],label='predict')
# ax.plot(date_time_predict[n_day+n_out-1:],inv_y[:],date_time_predict[n_day+n_out-1:],inv_yhat[:])
ax.legend(loc='upper right')
ax.set_title('Multivariate' +'  RMSE: %.2f' % rmse)
ax.set_xlabel('time')
ax.set_ylabel('s1 and s2')
ax.grid(True)


# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', alpha=0.5)


# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=8,
        verticalalignment='top', bbox=props)

plt.show()
