# %%
import ipywidgets as widgets
from IPython.display import display
from IPython.display import clear_output
import IPython
import IPython.display

import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from pandas import concat
from pandas import DataFrame

import datetime,os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import math
from math import sqrt

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
# File name and Path
cwd = os.getcwd()
path_adress = "/Import_Dataset/"

# ข้อมูล พิกัดสถานที่เเละรายชื้ออ้างอิงสถานที่ตรวจวัด
file_name_st = 'Data_lat_long_Rice research Center'
csv_file_st = cwd + path_adress + file_name_st + '.csv'

df_st = pd.read_csv(csv_file_st)
print("All low RiceCenter {} station" .format(df_st.shape[0]))

data_list_st_num = list(range(0, len(df_st)))
data_list_st_name = []
data_list_st_name = df_st['nameEng'].values.tolist()
data_list_st_lat = df_st['Latitude'].values.tolist()
data_list_st_long = df_st['Longitude'].values.tolist()

#################-- Moving Averag data --#################
def mavr_dataset(frames_sma,rolling_num,our_rate,mode):    
    h_name = list(frames_sma)
    if mode == 'sum':
        frames_sma['mirid bug'] = frames_sma['mirid bug'].rolling(rolling_num, min_periods=1).sum().round(1)
        frames_sma['bph'] = frames_sma['bph'].rolling(rolling_num, min_periods=1).sum().round(1)
        frames_sma['precip'] = frames_sma['precip'].rolling(rolling_num, min_periods=1).sum().round(1)
    else:
        frames_sma['mirid bug'] = frames_sma['mirid bug'].rolling(rolling_num, min_periods=1).mean().round(1)
        frames_sma['bph'] = frames_sma['bph'].rolling(rolling_num, min_periods=1).mean().round(1)
        frames_sma['precip'] = frames_sma['precip'].rolling(rolling_num, min_periods=1).mean().round(1)
   
    for i in range(7,12):
        frames_sma[h_name[i]] = frames_sma[h_name[i]].rolling(rolling_num, min_periods=1).mean().round(1)

    constant_subset = frames_sma[::our_rate] 
    return constant_subset

#################-- creat_dataset  --#################
def creat_dataset(st_BPH = 'ALL', y_1='2015', y_2='2019', m_avr='ALL'):
    for i in range(len(data_list_st_num)):
        st = i
        file_name = df_st['nameEng'][data_list_st_num[st]]
        name_input = file_name
        name_locals = 'stN_' + file_name

        # File name and Path
        csv_file = cwd + path_adress + name_input + '.csv'
        # index_col=0 , index_col=None
        dataset = pd.read_csv(csv_file, header=0,
                              index_col=0, encoding="TIS-620")

        if m_avr == '3-DAY-All-':
            locals()[name_locals] = mavr_dataset(dataset,3,1,'mean')
        elif m_avr == '7-DAY-All':
            locals()[name_locals] = mavr_dataset(dataset,7,1,'mean')
        elif m_avr == '14-DAY-All':
            locals()[name_locals] = mavr_dataset(dataset,14,1,'mean')
        elif m_avr == '3-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,3,3,'sum')
        elif m_avr == '7-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,7,7,'sum')
        elif m_avr == '14-DAY-Sampling':
            locals()[name_locals] = mavr_dataset(dataset,14,14,'sum')
        else :
            locals()[name_locals] = dataset
            # print(f'Dataframe name_station: {st+1 , name_input}')
        print('wait......')
        del dataset
        clear_output(wait=True)

    date_start = y_1 + '-01' + '-01'
    date_stop = y_2 + '-12' + '-31'

#---------------------------------------------------------------------------------------------------------------------------------------------------#
    if st_BPH != 'ALL' :
        # file_name = df_st['nameEng'][data_list_st_num[st_BPH]]
        file_name = st_BPH
        locals_input = 'stN_' + file_name
        print(locals_input)
        dataset_st = locals()[locals_input].loc[date_start:date_stop]
        frames_st = dataset_st
    else:
        m = 0
        for j in range(len(data_list_st_num)):
            # for j in range(df_st.shape[0]):
            # file_name = df_st['nameEng'][j]
            file_name = df_st['nameEng'][data_list_st_num[j]]
            locals_input = 'stN_' + file_name
            print(locals_input)
            dataset_st = locals()[locals_input].loc[date_start:date_stop]
            clear_output(wait=True)
            if m == 0:
                frames_st = dataset_st
                m = m+1
                print(m)
            else:
                frames_st = [frames_st, dataset_st]
                frames_st = pd.concat(frames_st)

    # dataset    
    frames = frames_st
    return frames
#---------------------------------------------------------------------------------------------------------------------------------------------------#

#################-- Drop Colum  --#################
def drop_col(df_drop,drop = ['address']):
    for j in range(len(drop)):
        df_drop = df_drop.drop(drop[j], axis=1)
    return df_drop

#################--      Plot        --#################
def plot_data(frames_train,plot_cols,df_name,start='2015',end='2017',st = 'ALL'):
    #ตรวจสอบข้อมูล dataset 
    if st == 'ALL':
        df_plot = frames_train[plot_cols]
    else:
        df_plot = frames_train[plot_cols].loc[start:end]
    
    plt.figure()    
    # df_plot.plot(lw=1,grid=True,figsize=(13,30),subplots=True)
    # df_plot.plot(lw=1,grid=True,subplots=True)
    # df_plot.plot(marker='.',grid=True,linestyle = 'solid',subplots=True)
    df_plot.plot(marker='.',grid=True,linestyle = 'solid')
    plt.xlabel('Date time-'+ df_name)
    plt.legend()
    # plt.show()   

#################--   get list of folders in directory   --#################
dir_path = cwd + "/Export_lstm/model/"
def get_list_folder():
    folder_list = os.listdir(dir_path)
    return folder_list

def get_file_model(file_name):
    txt = dir_path+file_name+"/Training_model_data_discription.txt"
    string_data = open(txt,"r").read()
    list_txt = list(string_data.split("\n"))
    return list_txt
# Out:
# All low RiceCenter 34 station

# %%
#########################################-- Dashboard Input Data--#########################################
ALL = 'ALL'

def unique_sorted_values_plus_ALL(array):
    unique = array.unique().tolist()
    unique.sort()
    unique.insert(0, ALL)
    return unique

#################-- DataFrame station --#################
output_df_st = widgets.Output()
def dropdown_station_eventhandler(change):
    output_df_st.clear_output()
    with output_df_st:  
        if (change.new == ALL):
            display(df_st)
        else:
            display(df_st[df_st.nameEng == change.new])

#################-- DataFrame station --#################
output_df_st_predict = widgets.Output()
def dropdown_station_predict_eventhandler(change):
    output_df_st_predict.clear_output()
    with output_df_st_predict:  
        if (change.new == ALL):
            display(df_st)
        else:
            display(df_st[df_st.nameEng == change.new])

#################-- load data  --#################


output_df_train = widgets.Output()
output_df_val = widgets.Output()
output_df_test = widgets.Output()
output_df_col = widgets.Output()
def clicked_load(b):
    global df_out_train
    global df_out_val
    global df_out_test
    global selected_data 
    output_df_train.clear_output()
    output_df_val.clear_output()
    output_df_test.clear_output()
    output_df_col.clear_output()
    with output_df_train:
        df_out_train = creat_dataset(dropdown_name_st.value,dropdown_year_train1.value,dropdown_year_train2.value,dropdown_sampling_data.value)
        display(df_out_train)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_train1.value,dropdown_year_train2.value,dropdown_sampling_data.value))
    with output_df_val:
        df_out_val = creat_dataset(dropdown_name_st.value,dropdown_year_val1.value,dropdown_year_val2.value,dropdown_sampling_data.value)
        display(df_out_val)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_val1.value,dropdown_year_val2.value,dropdown_sampling_data.value))
    with output_df_test:
        df_out_test = creat_dataset(dropdown_name_st.value,dropdown_year_test1.value,dropdown_year_test2.value,dropdown_sampling_data.value)
        display(df_out_test)
        # display(creat_dataset(dropdown_name_st.value,dropdown_year_test1.value,dropdown_year_test2.value,dropdown_sampling_data.value))
    with output_df_col:
        checkbox_objects = []
        # global selected_data
        data = sorted(set(chek_list(df_out_train)),reverse=True)     
        names = []
        for key in data:
                checkbox_objects.append(widgets.Checkbox(value=True, description=key))
                names.append(key)
 
        arg_dict = {names[i]: checkbox for i, checkbox in enumerate(checkbox_objects)}
        ui = widgets.HBox(children=checkbox_objects)
        display(ui)
             
        selected_data = []
        def select_data(**kwargs):
            selected_data.clear()
            for key in kwargs:
                if kwargs[key] is True:
                    selected_data.append(key)
            print(selected_data)

        widgets.interactive_output(select_data, arg_dict)
    
 
#################-- Export data  --#################
df_train = widgets.Output()
df_val = widgets.Output()
df_test = widgets.Output()
def clicked_export(b):
    df_train.clear_output()
    df_val.clear_output()
    df_test.clear_output()
    global frames_train
    global frames_val
    global frames_test
    with df_train:
        frames_train = drop_col(df_out_train,selected_data) 
        display(frames_train)
    with df_val:
        frames_val = drop_col(df_out_val,selected_data) 
        display(frames_val)  
    with df_test:
        frames_test = drop_col(df_out_test,selected_data) 
        display(frames_test)  

def chek_list(df_ch):
        data_col = set(df_ch.columns)
        return data_col      

#################----------------------------- DashBoard display ----------------------------------#################
dropdown_name_st = widgets.Dropdown(options = unique_sorted_values_plus_ALL(df_st.nameEng),description='station :')
dropdown_sampling_data = widgets.Dropdown(options = ['All','3-DAY-All','7-DAY-All','14-DAY-All','3-DAY-Sampling','7-DAY-Sampling','14-DAY-Sampling'],valure = 'All-DAY',description='Sampling :')
dropdown_year_train1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],description='Year-train :')
dropdown_year_train2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2017')
dropdown_year_val1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2018',description='Year-val :')
dropdown_year_val2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2018')
dropdown_year_test1 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2019',description='Year-test :')
dropdown_year_test2 = widgets.Dropdown(options = ['2015','2016','2017','2018','2019','2020'],value = '2019')


button_download = widgets.Button(description='load data',disabled=False,button_style='success',tooltip='Click me',icon='check')
button_export = widgets.Button(description='export dataset',disabled=False,button_style='success',tooltip='Click me',icon='check')

button_download.on_click(clicked_load)
button_export.on_click(clicked_export)

dropdown_name_st.observe(dropdown_station_eventhandler, names='value')


item_layout = widgets.Layout(margin='0 0 15px 0')
input_widgets_row1 = widgets.HBox([dropdown_name_st,dropdown_year_train1,dropdown_year_train2,dropdown_year_val1,dropdown_year_val2,dropdown_year_test1,dropdown_year_test2],layout = item_layout)
input_widgets_row2 = widgets.HBox([dropdown_sampling_data,button_download,button_export],layout = item_layout)

tab_dataset = widgets.Tab([output_df_st,output_df_train,output_df_val,output_df_test,output_df_col,df_train,df_val,df_test])
tab_dataset.set_title(0, 'Dataset station')
tab_dataset.set_title(1, 'train-data')
tab_dataset.set_title(2, 'validation-data')
tab_dataset.set_title(3, 'test-data')
tab_dataset.set_title(4, 'Drop-data')
tab_dataset.set_title(5, 'Dataset-train')
tab_dataset.set_title(6, 'Dataset-validation')
tab_dataset.set_title(7, 'Dataset-test')
dashboard_dataset = widgets.VBox([input_widgets_row1,input_widgets_row2])
display(dashboard_dataset)
display(tab_dataset)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='station :', options=('ALL', 'Chachoengsao Rice research Ce…
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), _titles={'0': '…

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
def plot_data(frames_train,df_name):
    #ตรวจสอบข้อมูล dataset 
    plt.figure()
    df_plot = frames_train
    df_plot.plot(lw=1,grid=True,subplots=True)
    plt.xlabel('Date time-'+ df_name)
    plt.legend()
    # plt.show()

# %%
day_of_month = frames_train['day'].values
month_of_year = frames_train['month'].values

frames_train['d_sin'] = np.sin((2*np.pi)/30*frames_train['day'].values)
frames_train['d_cos'] = np.cos((2*np.pi)/30*frames_train['day'].values)
frames_train['m_sin'] = np.sin((2*np.pi)/12*frames_train['month'].values)
frames_train['m_cos'] = np.cos((2*np.pi)/12*frames_train['month'].values)
frames_train = frames_train.drop(['day', 'month'], axis=1)

frames_val['d_sin'] = np.sin((2*np.pi)/30*frames_val['day'].values)
frames_val['d_cos'] = np.cos((2*np.pi)/30*frames_val['day'].values)
frames_val['m_sin'] = np.sin((2*np.pi)/12*frames_val['month'].values)
frames_val['m_cos'] = np.cos((2*np.pi)/12*frames_val['month'].values)
frames_val = frames_val.drop(['day', 'month'], axis=1)


frames_test['d_sin'] = np.sin((2*np.pi)/30*frames_test['day'].values)
frames_test['d_cos'] = np.cos((2*np.pi)/30*frames_test['day'].values)
frames_test['m_sin'] = np.sin((2*np.pi)/12*frames_test['month'].values)
frames_test['m_cos'] = np.cos((2*np.pi)/12*frames_test['month'].values)
frames_test = frames_test.drop(['day', 'month'], axis=1)

#define function to swap columns
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

#swap points and rebounds columns
frames_train = swap_columns(frames_train, 'bph', list(frames_train.columns)[-1])
frames_val = swap_columns(frames_val, 'bph', list(frames_val.columns)[-1])
frames_test = swap_columns(frames_test, 'bph', list(frames_test.columns)[-1])

# %%
values_train = frames_train.values    
n_features = frames_train.shape[1]

values_validation = frames_val.values

plot_data(frames_train,'1 station')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

n_day = 14
n_out = 7

#train data
# ensure all data is float
values = values_train.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)
# print(reframed.shape)
# print(reframed.head())

# predict datasets
values = reframed.values
train = values

#input 
n_obs = n_day * n_features
# train_X, train_y = train[:, :n_obs], train[:, -n_features]
train_X, train_y = train[:, :n_obs], train[:, -1]
print(train_X.shape, len(train_X), train_y.shape)  #for train


# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_day, n_features))
print(train_X.shape, train_y.shape)

#validation data
# ensure all data is float
values = values_validation.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)

# predict datasets
values = reframed.values
test = values

#output 
n_obs = n_day * n_features
# test_X, test_y = test[:, :n_obs], test[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(test_X.shape, len(test_X), test_y.shape)  #for train

# reshape input to be 3D [samples, timesteps, features]
test_X = test_X.reshape((test_X.shape[0], n_day, n_features))
print(test_X.shape, test_y.shape)


##------train-----##
model = tf.keras.models.Sequential([
                  # Shape [batch, time, features] => [batch, time, lstm_units]
                  keras.layers.LSTM(100, input_shape=(train_X.shape[1], train_X.shape[2]),activation='relu'),  #relu tanh
                  keras.layers.Dense(units=1)
    ])
# model = tf.keras.models.Sequential([
#                   # Shape [batch, time, features] => [batch, time, lstm_units]
#                   keras.layers.LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]),return_sequences=True,activation='relu'),
#                   keras.layers.BatchNormalization(),
#                   keras.layers.Dropout(0.1),
#                   keras.layers.LSTM(50, return_sequences=True, activation='relu'),
#                   keras.layers.BatchNormalization(),
#                   keras.layers.Dropout(0.1),
#                   keras.layers.LSTM(50, activation='relu'),
#                   keras.layers.BatchNormalization(),
#                   keras.layers.Dropout(0.1),
#                   keras.layers.Dense(units=1)
#             ])            
Optimizer = tf.keras.optimizers.Adam(0.0001)
model.compile(Optimizer, loss='mae', metrics=['accuracy'])
# model.summary()

# fit network
Epochs = 1000
batch_size = 128
history = model.fit(train_X, train_y, 
                    epochs=Epochs, 
                    batch_size=batch_size, 
                    validation_data=(test_X, test_y), 
                    verbose=2, 
                    # callbacks=[cp_callback,es_callback], 
                    shuffle=False)

# plot history
from matplotlib import pyplot as plt
def plot_loss(history):
    plt.figure()
    plt.plot(history.history['loss'], label='train')
    # plt.plot(history.history['val_loss'], label='val')
    plt.xlabel('Epoch')
    plt.ylabel('Error')
    plt.legend()
    plt.grid(True)
1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 26ms/step
# Epoch 201/1000
# 291/291 - 8s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 8s/epoch - 26ms/step
# Epoch 202/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 203/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 204/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 205/1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 206/1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 207/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 208/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 209/1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 210/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 211/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 212/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 213/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 214/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 215/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 216/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 217/1000
# 291/291 - 8s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 8s/epoch - 26ms/step
# Epoch 218/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 219/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 220/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 221/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 222/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 223/1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 224/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 225/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 226/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 227/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 228/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 229/1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 230/1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 231/1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 232/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 233/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 234/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 235/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 236/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 237/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 238/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 239/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 240/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 241/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 242/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 243/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 244/1000
# 291/291 - 7s - loss: 0.0020 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 245/1000
# 291/291 - 8s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 8s/epoch - 26ms/step
# Epoch 246/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 247/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 248/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 249/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 250/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 251/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 252/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 253/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 254/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 255/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 256/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 257/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 258/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 259/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 260/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 261/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 262/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 263/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0044 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 264/1000
# 291/291 - 8s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 8s/epoch - 26ms/step
# Epoch 265/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 266/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 267/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 268/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 269/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 270/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 271/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0044 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 272/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 273/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 274/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 275/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 276/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 277/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 278/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 279/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 280/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 281/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 282/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 283/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 284/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 285/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 286/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 287/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 288/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 289/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0044 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 290/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 291/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 292/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 293/1000
# 291/291 - 7s - loss: 0.0019 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 294/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 295/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0044 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 296/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 297/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0044 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 298/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 299/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0044 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 300/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 301/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 302/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 303/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 304/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 305/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 306/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 307/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 308/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 309/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 310/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 311/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 312/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 313/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 314/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 315/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 316/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 317/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 318/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 319/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0044 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 320/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 321/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 322/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 323/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 324/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 325/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 326/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 327/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 328/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 329/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 330/1000
# 291/291 - 8s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 8s/epoch - 26ms/step
# Epoch 331/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 332/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 333/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 334/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 335/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 336/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 337/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 338/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 339/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 340/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 341/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 342/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 343/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 344/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 345/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 346/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 347/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 348/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 349/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 350/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0045 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 351/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 352/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 25ms/step
# Epoch 353/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 354/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 355/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 356/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 357/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 358/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 359/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 360/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 361/1000
# 291/291 - 7s - loss: 0.0018 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 362/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 363/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 364/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 365/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0046 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 366/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 367/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 368/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 369/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 370/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 371/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 372/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 373/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 374/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 375/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0047 - val_accuracy: 0.4864 - 7s/epoch - 23ms/step
# Epoch 376/1000
# 291/291 - 7s - loss: 0.0017 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 7s/epoch - 24ms/step
# Epoch 377/1000
# ...
# Epoch 877/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 9s/epoch - 29ms/step
# Epoch 878/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 879/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 880/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 9s/epoch - 31ms/step
# Epoch 881/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 9s/epoch - 31ms/step
# Epoch 882/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 9s/epoch - 31ms/step
# Epoch 883/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 884/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 9s/epoch - 29ms/step
# Epoch 885/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 886/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 887/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 888/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 889/1000
# 291/291 - 8s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 8s/epoch - 29ms/step
# Epoch 890/1000
# 291/291 - 8s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 8s/epoch - 29ms/step
# Epoch 891/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 892/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 893/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 894/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 9s/epoch - 30ms/step
# Epoch 895/1000
# 291/291 - 9s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 9s/epoch - 32ms/step
# Epoch 896/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 37ms/step
# Epoch 897/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 898/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 899/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 900/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 901/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 902/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 903/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 904/1000
# 291/291 - 12s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 12s/epoch - 40ms/step
# Epoch 905/1000
# 291/291 - 12s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 12s/epoch - 41ms/step
# Epoch 906/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 907/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 908/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 909/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 910/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 911/1000
# 291/291 - 12s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 12s/epoch - 40ms/step
# Epoch 912/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 913/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 914/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 915/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 916/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 917/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 918/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 919/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 920/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0054 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 921/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 37ms/step
# Epoch 922/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 37ms/step
# Epoch 923/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 924/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 925/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 926/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 927/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 928/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 929/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 930/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 931/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 932/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 933/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 934/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 935/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 936/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 937/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 938/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 939/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 940/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 941/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 942/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 943/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 944/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 945/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 946/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 947/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 948/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 949/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 950/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 951/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 952/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 953/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 37ms/step
# Epoch 954/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 955/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 956/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 957/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0053 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 958/1000
# 291/291 - 12s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 12s/epoch - 41ms/step
# Epoch 959/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 960/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 961/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 962/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 963/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 964/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 965/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 966/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 967/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 968/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 969/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 970/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 971/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 972/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 973/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 974/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 975/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 976/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 977/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 978/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 979/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0052 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 980/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 981/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 982/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 37ms/step
# Epoch 983/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 984/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 985/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 986/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 987/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 988/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 989/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 990/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 991/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 992/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0051 - val_accuracy: 0.4864 - 11s/epoch - 39ms/step
# Epoch 993/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0048 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 994/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0050 - val_accuracy: 0.4864 - 11s/epoch - 37ms/step
# Epoch 995/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 996/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 997/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 998/1000
# 291/291 - 11s - loss: 0.0012 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 999/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step
# Epoch 1000/1000
# 291/291 - 11s - loss: 0.0013 - accuracy: 0.4066 - val_loss: 0.0049 - val_accuracy: 0.4864 - 11s/epoch - 38ms/step

# %%
values_predict = frames_test.values
n_features = frames_test.shape[1]
df = frames_test.reset_index()
date_time_predict = pd.to_datetime(df.pop('date'))

# ensure all data is float
values = values_predict.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
    
# frame as supervised learning
reframed = series_to_supervised(scaled, n_day, n_out)
# print(reframed.shape)
# print(reframed.head())
    
# predict datasets
values = reframed.values
# n_train_day = int(values.shape[0]*0.9)
# train = values[:n_train_day, :]
test = values
    
# predict into input and outputs
n_obs = n_day * n_features
# test_X, test_y = test[:, :n_obs], test[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -1]
print(test_X.shape, len(test_X), test_y.shape)
    
# reshape input to be 3D [samples, timesteps, features]
test_X = test_X.reshape((test_X.shape[0], n_day, n_features))
print(test_X.shape, test_y.shape)
    
# # make a prediction
yhat = model.predict(test_X,verbose=0)
test_X_reshape = test_X.reshape((test_X.shape[0], n_day*n_features)) 

from cProfile import label
from numpy import concatenate

# invert scaling for forecast
# inv_yhat = concatenate((yhat, test_X[:, -29:]), axis=1)
inv_yhat = concatenate((test_X_reshape[:, :(n_features-1)], yhat), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,-1]

# invert scaling for actual
test_y_reshape = test_y.reshape((len(test_y), 1))
# inv_y = concatenate((test_y, test_X[:, -29:]), axis=1)
inv_y = concatenate((test_X_reshape[:, :(n_features-1)], test_y_reshape), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]


d_range=60
pre_start = 200 #0 200
pre_stop = pre_start+d_range
d_start = n_day+n_out-1+pre_start
d_stop = n_day+n_out-1+pre_start+d_range

# calculate RMSE
m = tf.keras.metrics.RootMeanSquaredError()
m.update_state(inv_y[pre_start:pre_stop], inv_yhat[pre_start:pre_stop])
rmse = m.result().numpy()
print('RMSE: %.3f' % rmse)


strings = list(frames_test.columns)
textstr = '\n'.join(strings)


fig, ax = plt.subplots()

# ax.plot(date_time_predict[n_day+n_out-1:],inv_y[:],label='actual')
# ax.plot(date_time_predict[n_day+n_out-1:],inv_yhat[:],label='predict')

ax.plot(date_time_predict[d_start:d_stop],inv_y[pre_start:pre_stop],label='actual')
ax.plot(date_time_predict[d_start:d_stop],inv_yhat[pre_start:pre_stop],label='predict')

ax.legend(loc='upper right')
ax.set_title('Multivariate' +'  RMSE: %.2f' % rmse)
ax.set_xlabel('time (day) '+'(%d-'%n_day+'%d-'%n_out+'Epoch %d)'%Epochs)
ax.set_ylabel('BPH Volume')
ax.grid(True)

# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=8,
        verticalalignment='top', bbox=props)
plt.show()
# Out:
# (12390, 84) 12390 (12390,)
# (12390, 14, 6) (12390,)
# RMSE: 76.442
